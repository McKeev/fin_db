# %%
import os
import time

import refinitiv.data as rd
import pandas as pd
import yfinance as yf
from openai import OpenAI
from pydantic import BaseModel, Field

rd.open_session(os.getenv('REFINITIV_API_KEY'))
try:
    client = OpenAI(api_key=os.getenv("OPENAI_KEY"))
except Exception as e:
    raise e

# %% [markdown]
# ## Getting the Equities set up

# %%
ETFs = {
    'SPDR S&P 500 ETF Trust': 'SPY',
    'SPDR Dow Jones Industrial Average ETF Trust': 'DIA',
    'Invesco NASDAQ 100 ETF': 'QQQM.O',
    'Vanguard FTSE 100 ETF': 'VUKE.L',
    'Xtrackers CAC 40 UCITS ETF': 'XCAC.DE',
    'Global X DAX Germany ETF': 'DAX.O',
    'State Street SPDR EURO STOXX 50 ETF': 'FEZ',
}

# %%
tickers = []
for _, etf_ric in ETFs.items():
    print(f"Fetching constituents for ETF: {etf_ric}")
    constituents = rd.get_data(
        universe=[etf_ric],
        fields=['TR.FundHoldingRIC'],
        use_field_names_in_headers=True,
        parameters={'Endnum': '5000'}
    )
    cleaned = constituents[('TR.FundHoldingRIC').upper()].dropna().tolist()
    print(f"Found {len(cleaned)} constituents.")
    tickers.extend(cleaned)
# Out:
# Fetching constituents for ETF: SPY
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/_access_layer/get_data_func.py:57:FutureWarning: Parameter 'use_field_names_in_headers' is deprecated and will be removed in future library version v2.0.
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/content/fundamental_and_reference/_definition.py:147:FutureWarning: Parameter 'use_field_names_in_headers' is deprecated and will be removed in future library version v2.0.
# Found 503 constituents.
# Fetching constituents for ETF: DIA
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/_access_layer/get_data_func.py:57:FutureWarning: Parameter 'use_field_names_in_headers' is deprecated and will be removed in future library version v2.0.
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/content/fundamental_and_reference/_definition.py:147:FutureWarning: Parameter 'use_field_names_in_headers' is deprecated and will be removed in future library version v2.0.
# Found 30 constituents.
# Fetching constituents for ETF: QQQM.O
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/_access_layer/get_data_func.py:57:FutureWarning: Parameter 'use_field_names_in_headers' is deprecated and will be removed in future library version v2.0.
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/content/fundamental_and_reference/_definition.py:147:FutureWarning: Parameter 'use_field_names_in_headers' is deprecated and will be removed in future library version v2.0.
# Found 103 constituents.
# Fetching constituents for ETF: VUKE.L
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/_access_layer/get_data_func.py:57:FutureWarning: Parameter 'use_field_names_in_headers' is deprecated and will be removed in future library version v2.0.
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/content/fundamental_and_reference/_definition.py:147:FutureWarning: Parameter 'use_field_names_in_headers' is deprecated and will be removed in future library version v2.0.
# Found 102 constituents.
# Fetching constituents for ETF: XCAC.DE
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/_access_layer/get_data_func.py:57:FutureWarning: Parameter 'use_field_names_in_headers' is deprecated and will be removed in future library version v2.0.
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/content/fundamental_and_reference/_definition.py:147:FutureWarning: Parameter 'use_field_names_in_headers' is deprecated and will be removed in future library version v2.0.
# Found 41 constituents.
# Fetching constituents for ETF: DAX.O
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/_access_layer/get_data_func.py:57:FutureWarning: Parameter 'use_field_names_in_headers' is deprecated and will be removed in future library version v2.0.
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/content/fundamental_and_reference/_definition.py:147:FutureWarning: Parameter 'use_field_names_in_headers' is deprecated and will be removed in future library version v2.0.
# Found 40 constituents.
# Fetching constituents for ETF: FEZ
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/_access_layer/get_data_func.py:57:FutureWarning: Parameter 'use_field_names_in_headers' is deprecated and will be removed in future library version v2.0.
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/content/fundamental_and_reference/_definition.py:147:FutureWarning: Parameter 'use_field_names_in_headers' is deprecated and will be removed in future library version v2.0.
# Found 51 constituents.

# %%
tickers.extend([   # Add tickers relevant to personal use
    'ALLY.K', 'BABA.K', 'CNI.N', 'DHT.N', 'DSV.CO', 'FND.N', 'FRO.N',
    'GNK.N', 'GOGL.O', 'GXO.N', 'HUBG.O', 'ICGA.DE', 'INSW.K', 'KEX.N',
    'LLYVK.OQ', 'LPGAS', 'LPX.N', 'LSTR.O', 'MANH.O', 'NU.N', 'R.N',
    'SAIA.OQ', 'SBLK.O', 'SIRI.O', 'SNOW.K', 'SOLB.BR', 'STZ.N', 'TSM.N',
    'UBSG.S'
])
unique_tickers = list(set(tickers))
unique_tickers.sort()
print(len(unique_tickers))
# Out:
# 747

# %%
# Get data
desired = [
    'TR.CommonName',
    'TR.ExchangeCode',
    'TR.HQCountryCode',
    'CF_CURR',
    'TR.GICSSubIndustryCode',
]

equities = rd.get_data(
    universe=unique_tickers,
    fields=desired,
    parameters={'Endnum': '5000'}
)

# Identify empty strings as NaN
equities = equities.replace('', pd.NA)
# Out:
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/_access_layer/get_data_func.py:99:UserWarning: 'parameters' is not applicable for fields ['CF_CURR']
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/_tools/_dataframe.py:192:FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
# Drop equities with no name or empty string
equities = equities.dropna(subset=['Company Common Name'])

# Display non-unique common names
non_unique_names = equities['Company Common Name'].value_counts()
problems = non_unique_names[non_unique_names > 1].index.tolist()
print(equities[equities['Company Common Name'].isin(problems)])
# Out:
#     Instrument Company Common Name Exchange Code  \
# 62     ASML.AS     ASML Holding NV           AEX
# 63     ASML.OQ     ASML Holding NV           NSM
# 284     FOX.OQ            Fox Corp           NSM
# 285    FOXA.OQ            Fox Corp           NSM
# 311    GOOG.OQ        Alphabet Inc           NSM
# 312   GOOGL.OQ        Alphabet Inc           NSM
# 509     NWS.OQ           News Corp           NSM
# 510    NWSA.OQ           News Corp           NSM
#
#     Country ISO Code of Headquarters  GICS Sub-Industry Code CF_CURR
# 62                                NL                45301010     EUR
# 63                                NL                45301010     USD
# 284                               US                50201020     USD
# 285                               US                50201020     USD
# 311                               US                50203010     USD
# 312                               US                50203010     USD
# 509                               US                50201040     USD
# 510                               US                50201040     USD

# %%
# Drop, id rather the ADR
equities= equities[equities['Instrument'] != 'ASML.AS']

# Append to name
class_a = ['FOXA.OQ', 'GOOGL.OQ', 'NWSA.OQ']
for name in class_a:
    equities.loc[equities['Instrument'] == name, 'Company Common Name'] += ' (Class A)'
class_b = ['FOX.OQ', 'NWS.OQ']
for name in class_b:
    equities.loc[equities['Instrument'] == name, 'Company Common Name'] += ' (Class B)'
equities.loc[equities['Instrument'] == 'BRK.B', 'Company Common Name'] += ' (Class C)'
# Also, theres not a lot of rows without GICS code
print(equities[equities['GICS Sub-Industry Code'].isna()]['Company Common Name'])
# Out:
# 39                                    Alliance Witan PLC
# 269                             F&C Investment Trust PLC
# 310                               Golden Ocean Group Ltd
# 356                 iShares MSCI China UCITS ETF USD Acc
# 424                Invesco Government & Agency Portfolio
# 425    State Street Institutional Government Money Ma...
# 529                   Polar Capital Technology Trust PLC
# 558                         Pershing Square Holdings Ltd
# 622               Scottish Mortgage Investment Trust PLC
# Name: Company Common Name, dtype: string

# %%
# Drop! Some werent equities -> filtering on this ensures equities
equities = equities.dropna(subset=['GICS Sub-Industry Code'])

# After that step, only 2 NAs left, so might as well drop them too
equities = equities.dropna()

# %%
EXCHANGE_CODE_TO_NAME = {
    'NYS': 'New York Stock Exchange',
    'NYQ': 'New York Stock Exchange',
    'NSM': 'NASDAQ',
    'NSQ': 'NASDAQ',
    'NMS': 'NASDAQ',
    'BAT': 'BATS Exchange',
    'LSE': 'London Stock Exchange',
    'BRU': 'Euronext Brussels',
    'PAR': 'Euronext Paris',
    'AEX': 'Euronext Amsterdam',
    'GER': 'Deutsche Börse (Frankfurt)',
    'MCE': 'Bolsa de Madrid',
    'MIL': 'Borsa Italiana (Milan)',
    'CPH': 'Nasdaq Copenhagen',
    'TOR': 'Toronto Stock Exchange',
    'HEX': 'Nasdaq Helsinki',
    'VTX': 'SIX Swiss Exchange',
}

firm_exchange = list(zip(
    equities['Instrument'],
    equities["Company Common Name"],
    equities['Exchange Code'].map(EXCHANGE_CODE_TO_NAME)
))
firm_exchange
# Out:
# [('A.N', 'Agilent Technologies Inc', 'New York Stock Exchange'),
#  ('AAF.L', 'Airtel Africa PLC', 'London Stock Exchange'),
#  ('AAL.L', 'Anglo American PLC', 'London Stock Exchange'),
#  ('AAPL.OQ', 'Apple Inc', 'NASDAQ'),
#  ('ABBV.N', 'AbbVie Inc', 'New York Stock Exchange'),
#  ('ABF.L', 'Associated British Foods PLC', 'London Stock Exchange'),
#  ('ABI.BR', 'Anheuser-Busch Inbev SA', 'Euronext Brussels'),
#  ('ABNB.OQ', 'Airbnb Inc', 'NASDAQ'),
#  ('ABT.N', 'Abbott Laboratories', 'New York Stock Exchange'),
#  ('ACCP.PA', 'Accor SA', 'Euronext Paris'),
#  ('ACGL.OQ', 'Arch Capital Group Ltd', 'NASDAQ'),
#  ('ACN.N', 'Accenture PLC', 'New York Stock Exchange'),
#  ('AD.AS', 'Koninklijke Ahold Delhaize NV', 'Euronext Amsterdam'),
#  ('ADBE.OQ', 'Adobe Inc', 'NASDAQ'),
#  ('ADI.OQ', 'Analog Devices Inc', 'NASDAQ'),
#  ('ADM.N', 'Archer-Daniels-Midland Co', 'New York Stock Exchange'),
#  ('ADML.L', 'Admiral Group PLC', 'London Stock Exchange'),
#  ('ADP.OQ', 'Automatic Data Processing Inc', 'NASDAQ'),
#  ('ADSGn.DE', 'Adidas AG', 'Deutsche Börse (Frankfurt)'),
#  ('ADSK.OQ', 'Autodesk Inc', 'NASDAQ'),
#  ('ADYEN.AS', 'Adyen NV', 'Euronext Amsterdam'),
#  ('AEE.N', 'Ameren Corp', 'New York Stock Exchange'),
#  ('AEP.OQ', 'American Electric Power Company Inc', 'NASDAQ'),
#  ('AES.N', 'AES Corp', 'New York Stock Exchange'),
#  ('AFL.N', 'Aflac Inc', 'New York Stock Exchange'),
#  ('AHT.L', 'Ashtead Group PLC', 'London Stock Exchange'),
#  ('AIG.N', 'American International Group Inc', 'New York Stock Exchange'),
#  ('AIR.PA', 'Airbus SE', 'Euronext Paris'),
#  ('AIRP.PA',
#   "L'Air Liquide Societe Anonyme pour l'Etude et l'Exploitation des Procedes Georges Claude SA",
#   'Euronext Paris'),
#  ('AIZ.N', 'Assurant Inc', 'New York Stock Exchange'),
#  ('AJG.N', 'Arthur J. Gallagher & Co.', 'New York Stock Exchange'),
#  ('AKAM.OQ', 'Akamai Technologies Inc', 'NASDAQ'),
#  ('ALB.N', 'Albemarle Corp', 'New York Stock Exchange'),
#  ('ALGN.OQ', 'Align Technology Inc', 'NASDAQ'),
#  ('ALL.N', 'Allstate Corp', 'New York Stock Exchange'),
#  ('ALLE.N', 'Allegion PLC', 'New York Stock Exchange'),
#  ('ALLY.K', 'Ally Financial Inc', 'New York Stock Exchange'),
#  ('ALNY.OQ', 'Alnylam Pharmaceuticals Inc', 'NASDAQ'),
#  ('ALVG.DE', 'Allianz SE', 'Deutsche Börse (Frankfurt)'),
#  ('AMAT.OQ', 'Applied Materials Inc', 'NASDAQ'),
#  ('AMCR.N', 'Amcor PLC', 'New York Stock Exchange'),
#  ('AMD.OQ', 'Advanced Micro Devices Inc', 'NASDAQ'),
#  ('AME.N', 'AMETEK Inc', 'New York Stock Exchange'),
#  ('AMGN.OQ', 'Amgen Inc', 'NASDAQ'),
#  ('AMP.N', 'Ameriprise Financial Inc', 'New York Stock Exchange'),
#  ('AMT.N', 'American Tower Corp', 'New York Stock Exchange'),
#  ('AMZN.OQ', 'Amazon.com Inc', 'NASDAQ'),
#  ('ANET.N', 'Arista Networks Inc', 'New York Stock Exchange'),
#  ('ANTO.L', 'Antofagasta PLC', 'London Stock Exchange'),
#  ('AON.N', 'Aon PLC', 'New York Stock Exchange'),
#  ('AOS.N', 'A O Smith Corp', 'New York Stock Exchange'),
#  ('APA.OQ', 'APA Corp (US)', 'NASDAQ'),
#  ('APD.N', 'Air Products and Chemicals Inc', 'New York Stock Exchange'),
#  ('APH.N', 'Amphenol Corp', 'New York Stock Exchange'),
#  ('APO.N', 'Apollo Global Management Inc', 'New York Stock Exchange'),
#  ('APP.OQ', 'Applovin Corp', 'NASDAQ'),
#  ('APTV.N', 'Aptiv PLC', 'New York Stock Exchange'),
#  ('ARE.N', 'Alexandria Real Estate Equities Inc', 'New York Stock Exchange'),
#  ('ARES.N', 'Ares Management Corp', 'New York Stock Exchange'),
#  ('ARGX.BR', 'argenx SE', 'Euronext Brussels'),
#  ('ARM.OQ', 'Arm Holdings PLC', 'NASDAQ'),
#  ('ASML.OQ', 'ASML Holding NV', 'NASDAQ'),
#  ('ATO.N', 'Atmos Energy Corp', 'New York Stock Exchange'),
#  ('AUTOA.L', 'Autotrader Group PLC', 'London Stock Exchange'),
#  ('AV.L', 'Aviva PLC', 'London Stock Exchange'),
#  ('AVB.N', 'AvalonBay Communities Inc', 'New York Stock Exchange'),
#  ('AVGO.OQ', 'Broadcom Inc', 'NASDAQ'),
#  ('AVY.N', 'Avery Dennison Corp', 'New York Stock Exchange'),
#  ('AWK.N', 'American Water Works Co Inc', 'New York Stock Exchange'),
#  ('AXAF.PA', 'AXA SA', 'Euronext Paris'),
#  ('AXON.OQ', 'Axon Enterprise Inc', 'NASDAQ'),
#  ('AXP.N', 'American Express Co', 'New York Stock Exchange'),
#  ('AZN.L', 'AstraZeneca PLC', 'London Stock Exchange'),
#  ('AZO.N', 'Autozone Inc', 'New York Stock Exchange'),
#  ('BA.N', 'Boeing Co', 'New York Stock Exchange'),
#  ('BAB.L', 'Babcock International Group PLC', 'London Stock Exchange'),
#  ('BABA.K', 'Alibaba Group Holding Ltd', 'New York Stock Exchange'),
#  ('BAC.N', 'Bank of America Corp', 'New York Stock Exchange'),
#  ('BAES.L', 'BAE Systems PLC', 'London Stock Exchange'),
#  ('BALL.N', 'Ball Corp', 'New York Stock Exchange'),
#  ('BARC.L', 'Barclays PLC', 'London Stock Exchange'),
#  ('BASFn.DE', 'BASF SE', 'Deutsche Börse (Frankfurt)'),
#  ('BATS.L', 'British American Tobacco plc', 'London Stock Exchange'),
#  ('BAX.N', 'Baxter International Inc', 'New York Stock Exchange'),
#  ('BAYGn.DE', 'Bayer AG', 'Deutsche Börse (Frankfurt)'),
#  ('BBVA.MC', 'Banco Bilbao Vizcaya Argentaria SA', 'Bolsa de Madrid'),
#  ('BBY.N', 'Best Buy Co Inc', 'New York Stock Exchange'),
#  ('BDX.N', 'Becton Dickinson and Co', 'New York Stock Exchange'),
#  ('BEIG.DE', 'Beiersdorf AG', 'Deutsche Börse (Frankfurt)'),
#  ('BEN.N', 'Franklin Resources Inc', 'New York Stock Exchange'),
#  ('BEZG.L', 'Beazley PLC', 'London Stock Exchange'),
#  ('BFb.N', 'Brown-Forman Corp', 'New York Stock Exchange'),
#  ('BG.N', 'Bunge Global ltd', 'New York Stock Exchange'),
#  ('BIIB.OQ', 'Biogen Inc', 'NASDAQ'),
#  ('BK.N', 'Bank of New York Mellon Corp', 'New York Stock Exchange'),
#  ('BKGH.L', 'Berkeley Group Holdings PLC', 'London Stock Exchange'),
#  ('BKNG.OQ', 'Booking Holdings Inc', 'NASDAQ'),
#  ('BKR.OQ', 'Baker Hughes Co', 'NASDAQ'),
#  ('BLDR.N', 'Builders FirstSource Inc', 'New York Stock Exchange'),
#  ('BLK.N', 'BlackRock Inc', 'New York Stock Exchange'),
#  ('BLND.L', 'British Land Company PLC', 'London Stock Exchange'),
#  ('BMWG.DE', 'Bayerische Motoren Werke AG', 'Deutsche Börse (Frankfurt)'),
#  ('BMY.N', 'Bristol-Myers Squibb Co', 'New York Stock Exchange'),
#  ('BNPP.PA', 'BNP Paribas SA', 'Euronext Paris'),
#  ('BNRGn.DE', 'Brenntag SE', 'Deutsche Börse (Frankfurt)'),
#  ('BNZL.L', 'Bunzl plc', 'London Stock Exchange'),
#  ('BOUY.PA', 'Bouygues SA', 'Euronext Paris'),
#  ('BP.L', 'BP PLC', 'London Stock Exchange'),
#  ('BR.N', 'Broadridge Financial Solutions Inc', 'New York Stock Exchange'),
#  ('BRBY.L', 'Burberry Group PLC', 'London Stock Exchange'),
#  ('BRKb.N', 'Berkshire Hathaway Inc', 'New York Stock Exchange'),
#  ('BRO.N', 'Brown & Brown Inc', 'New York Stock Exchange'),
#  ('BSX.N', 'Boston Scientific Corp', 'New York Stock Exchange'),
#  ('BT.L', 'BT Group PLC', 'London Stock Exchange'),
#  ('BTRW.L', 'Barratt Redrow PLC', 'London Stock Exchange'),
#  ('BVI.PA', 'Bureau Veritas SA', 'Euronext Paris'),
#  ('BX.N', 'Blackstone Inc', 'New York Stock Exchange'),
#  ('BXP.N', 'BXP Inc', 'New York Stock Exchange'),
#  ('C.N', 'Citigroup Inc', 'New York Stock Exchange'),
#  ('CAG.N', 'Conagra Brands Inc', 'New York Stock Exchange'),
#  ('CAGR.PA', 'Credit Agricole SA', 'Euronext Paris'),
#  ('CAH.N', 'Cardinal Health Inc', 'New York Stock Exchange'),
#  ('CAPP.PA', 'Capgemini SE', 'Euronext Paris'),
#  ('CARR.N', 'Carrier Global Corp', 'New York Stock Exchange'),
#  ('CARR.PA', 'Carrefour SA', 'Euronext Paris'),
#  ('CAT.N', 'Caterpillar Inc', 'New York Stock Exchange'),
#  ('CB.N', 'Chubb Ltd', 'New York Stock Exchange'),
#  ('CBKG.DE', 'Commerzbank AG', 'Deutsche Börse (Frankfurt)'),
#  ('CBOE.Z', 'Cboe Global Markets Inc', 'BATS Exchange'),
#  ('CBRE.N', 'CBRE Group Inc', 'New York Stock Exchange'),
#  ('CCEP.OQ', 'Coca-Cola Europacific Partners PLC', 'NASDAQ'),
#  ('CCH.L', 'Coca Cola HBC AG', 'London Stock Exchange'),
#  ('CCI.N', 'Crown Castle Inc', 'New York Stock Exchange'),
#  ('CCL.N', 'Carnival Corp', 'New York Stock Exchange'),
#  ('CDNS.OQ', 'Cadence Design Systems Inc', 'NASDAQ'),
#  ('CDW.OQ', 'CDW Corp', 'NASDAQ'),
#  ('CEG.OQ', 'Constellation Energy Corp', 'NASDAQ'),
#  ('CF.N', 'CF Industries Holdings Inc', 'New York Stock Exchange'),
#  ('CFG.N', 'Citizens Financial Group Inc', 'New York Stock Exchange'),
#  ('CHD.N', 'Church & Dwight Co Inc', 'New York Stock Exchange'),
#  ('CHRW.OQ', 'CH Robinson Worldwide Inc', 'NASDAQ'),
#  ('CHTR.OQ', 'Charter Communications Inc', 'NASDAQ'),
#  ('CI.N', 'Cigna Group', 'New York Stock Exchange'),
#  ('CINF.OQ', 'Cincinnati Financial Corp', 'NASDAQ'),
#  ('CL.N', 'Colgate-Palmolive Co', 'New York Stock Exchange'),
#  ('CLX.N', 'Clorox Co', 'New York Stock Exchange'),
#  ('CMCSA.OQ', 'Comcast Corp', 'NASDAQ'),
#  ('CME.OQ', 'CME Group Inc', 'NASDAQ'),
#  ('CMG.N', 'Chipotle Mexican Grill Inc', 'New York Stock Exchange'),
#  ('CMI.N', 'Cummins Inc', 'New York Stock Exchange'),
#  ('CMS.N', 'CMS Energy Corp', 'New York Stock Exchange'),
#  ('CNA.L', 'Centrica PLC', 'London Stock Exchange'),
#  ('CNC.N', 'Centene Corp', 'New York Stock Exchange'),
#  ('CNI.N', 'Canadian National Railway Co', 'New York Stock Exchange'),
#  ('CNP.N', 'CenterPoint Energy Inc', 'New York Stock Exchange'),
#  ('COF.N', 'Capital One Financial Corp', 'New York Stock Exchange'),
#  ('COIN.OQ', 'Coinbase Global Inc', 'NASDAQ'),
#  ('CONG.DE', 'Continental AG', 'Deutsche Börse (Frankfurt)'),
#  ('COO.OQ', 'Cooper Companies Inc', 'NASDAQ'),
#  ('COP.N', 'ConocoPhillips', 'New York Stock Exchange'),
#  ('COR.N', 'Cencora Inc', 'New York Stock Exchange'),
#  ('COST.OQ', 'Costco Wholesale Corp', 'NASDAQ'),
#  ('CPAY.N', 'Corpay Inc', 'New York Stock Exchange'),
#  ('CPB.OQ', "Campbell's Co", 'NASDAQ'),
#  ('CPG.L', 'Compass Group PLC', 'London Stock Exchange'),
#  ('CPRT.OQ', 'Copart Inc', 'NASDAQ'),
#  ('CPT.N', 'Camden Property Trust', 'New York Stock Exchange'),
#  ('CRDA.L', 'Croda International PLC', 'London Stock Exchange'),
#  ('CRDI.MI', 'UniCredit SpA', 'Borsa Italiana (Milan)'),
#  ('CRH.N', 'CRH PLC', 'New York Stock Exchange'),
#  ('CRL.N',
#   'Charles River Laboratories International Inc',
#   'New York Stock Exchange'),
#  ('CRM.N', 'Salesforce Inc', 'New York Stock Exchange'),
#  ('CRWD.OQ', 'CrowdStrike Holdings Inc', 'NASDAQ'),
#  ('CSCO.OQ', 'Cisco Systems Inc', 'NASDAQ'),
#  ('CSGP.OQ', 'CoStar Group Inc', 'NASDAQ'),
#  ('CSX.OQ', 'CSX Corp', 'NASDAQ'),
#  ('CTAS.OQ', 'Cintas Corp', 'NASDAQ'),
#  ('CTEC.L', 'ConvaTec Group PLC', 'London Stock Exchange'),
#  ('CTRA.N', 'Coterra Energy Inc', 'New York Stock Exchange'),
#  ('CTSH.OQ', 'Cognizant Technology Solutions Corp', 'NASDAQ'),
#  ('CTVA.N', 'Corteva Inc', 'New York Stock Exchange'),
#  ('CVNA.N', 'Carvana Co', 'New York Stock Exchange'),
#  ('CVS.N', 'CVS Health Corp', 'New York Stock Exchange'),
#  ('CVX.N', 'Chevron Corp', 'New York Stock Exchange'),
#  ('D.N', 'Dominion Energy Inc', 'New York Stock Exchange'),
#  ('DAL.N', 'Delta Air Lines Inc', 'New York Stock Exchange'),
#  ('DANO.PA', 'Danone SA', 'Euronext Paris'),
#  ('DASH.OQ', 'DoorDash Inc', 'NASDAQ'),
#  ('DAST.PA', 'Dassault Systemes SE', 'Euronext Paris'),
#  ('DB1Gn.DE', 'Deutsche Boerse AG', 'Deutsche Börse (Frankfurt)'),
#  ('DBKGn.DE', 'Deutsche Bank AG', 'Deutsche Börse (Frankfurt)'),
#  ('DCC.L', 'DCC PLC', 'London Stock Exchange'),
#  ('DD.N', 'Dupont De Nemours Inc', 'New York Stock Exchange'),
#  ('DDOG.OQ', 'Datadog Inc', 'NASDAQ'),
#  ('DE.N', 'Deere & Co', 'New York Stock Exchange'),
#  ('DECK.N', 'Deckers Outdoor Corp', 'New York Stock Exchange'),
#  ('DELL.N', 'Dell Technologies Inc', 'New York Stock Exchange'),
#  ('DG.N', 'Dollar General Corp', 'New York Stock Exchange'),
#  ('DGE.L', 'Diageo PLC', 'London Stock Exchange'),
#  ('DGX.N', 'Quest Diagnostics Inc', 'New York Stock Exchange'),
#  ('DHI.N', 'D.R. Horton Inc', 'New York Stock Exchange'),
#  ('DHLn.DE', 'Deutsche Post AG', 'Deutsche Börse (Frankfurt)'),
#  ('DHR.N', 'Danaher Corp', 'New York Stock Exchange'),
#  ('DHT.N', 'DHT Holdings Inc', 'New York Stock Exchange'),
#  ('DIS.N', 'Walt Disney Co', 'New York Stock Exchange'),
#  ('DLR.N', 'Digital Realty Trust Inc', 'New York Stock Exchange'),
#  ('DLTR.OQ', 'Dollar Tree Inc', 'NASDAQ'),
#  ('DOC.N', 'Healthpeak Properties Inc', 'New York Stock Exchange'),
#  ('DOV.N', 'Dover Corp', 'New York Stock Exchange'),
#  ('DOW.N', 'Dow Inc', 'New York Stock Exchange'),
#  ('DPLM.L', 'Diploma PLC', 'London Stock Exchange'),
#  ('DPZ.OQ', "Domino's Pizza Inc", 'NASDAQ'),
#  ('DRI.N', 'Darden Restaurants Inc', 'New York Stock Exchange'),
#  ('DSV.CO', 'DSV A/S', 'Nasdaq Copenhagen'),
#  ('DTE.N', 'DTE Energy Co', 'New York Stock Exchange'),
#  ('DTEGn.DE', 'Deutsche Telekom AG', 'Deutsche Börse (Frankfurt)'),
#  ('DTGGe.DE', 'Daimler Truck Holding AG', 'Deutsche Börse (Frankfurt)'),
#  ('DUK.N', 'Duke Energy Corp', 'New York Stock Exchange'),
#  ('DVA.N', 'DaVita Inc', 'New York Stock Exchange'),
#  ('DVN.N', 'Devon Energy Corp', 'New York Stock Exchange'),
#  ('DXCM.OQ', 'Dexcom Inc', 'NASDAQ'),
#  ('EA.OQ', 'Electronic Arts Inc', 'NASDAQ'),
#  ('EBAY.OQ', 'eBay Inc', 'NASDAQ'),
#  ('ECL.N', 'Ecolab Inc', 'New York Stock Exchange'),
#  ('ED.N', 'Consolidated Edison Inc', 'New York Stock Exchange'),
#  ('EDV.TO', 'Endeavour Mining plc', 'Toronto Stock Exchange'),
#  ('EFX.N', 'Equifax Inc', 'New York Stock Exchange'),
#  ('EG.N', 'Everest Group Ltd', 'New York Stock Exchange'),
#  ('EIX.N', 'Edison International', 'New York Stock Exchange'),
#  ('EL.N', 'Estee Lauder Companies Inc', 'New York Stock Exchange'),
#  ('ELV.N', 'Elevance Health Inc', 'New York Stock Exchange'),
#  ('EME.N', 'EMCOR Group Inc', 'New York Stock Exchange'),
#  ('EMR.N', 'Emerson Electric Co', 'New York Stock Exchange'),
#  ('ENEI.MI', 'Enel SpA', 'Borsa Italiana (Milan)'),
#  ('ENGIE.PA', 'Engie SA', 'Euronext Paris'),
#  ('ENI.MI', 'Eni SpA', 'Borsa Italiana (Milan)'),
#  ('ENR1n.DE', 'Siemens Energy AG', 'Deutsche Börse (Frankfurt)'),
#  ('ENT.L', 'Entain PLC', 'London Stock Exchange'),
#  ('ENX.PA', 'Euronext NV', 'Euronext Paris'),
#  ('EOG.N', 'EOG Resources Inc', 'New York Stock Exchange'),
#  ('EONGn.DE', 'E.ON SE', 'Deutsche Börse (Frankfurt)'),
#  ('EPAM.N', 'Epam Systems Inc', 'New York Stock Exchange'),
#  ('EQIX.OQ', 'Equinix Inc', 'NASDAQ'),
#  ('EQR.N', 'Equity Residential', 'New York Stock Exchange'),
#  ('EQT.N', 'EQT Corp', 'New York Stock Exchange'),
#  ('ERIE.OQ', 'Erie Indemnity Co', 'NASDAQ'),
#  ('ES.N', 'Eversource Energy', 'New York Stock Exchange'),
#  ('ESLX.PA', 'EssilorLuxottica SA', 'Euronext Paris'),
#  ('ESS.N', 'Essex Property Trust Inc', 'New York Stock Exchange'),
#  ('ETN.N', 'Eaton Corporation PLC', 'New York Stock Exchange'),
#  ('ETR.N', 'Entergy Corp', 'New York Stock Exchange'),
#  ('EUFI.PA', 'Eurofins Scientific SE', 'Euronext Paris'),
#  ('EVRE.L', 'EVRAZ plc', 'London Stock Exchange'),
#  ('EVRG.OQ', 'Evergy Inc', 'NASDAQ'),
#  ('EW.N', 'Edwards Lifesciences Corp', 'New York Stock Exchange'),
#  ('EXC.OQ', 'Exelon Corp', 'NASDAQ'),
#  ('EXE.OQ', 'Expand Energy Corp', 'NASDAQ'),
#  ('EXPD.N',
#   'Expeditors International of Washington Inc',
#   'New York Stock Exchange'),
#  ('EXPE.OQ', 'Expedia Group Inc', 'NASDAQ'),
#  ('EXPN.L', 'Experian PLC', 'London Stock Exchange'),
#  ('EXR.N', 'Extra Space Storage Inc', 'New York Stock Exchange'),
#  ('EZJ.L', 'Easyjet PLC', 'London Stock Exchange'),
#  ('F.N', 'Ford Motor Co', 'New York Stock Exchange'),
#  ('FANG.OQ', 'Diamondback Energy Inc', 'NASDAQ'),
#  ('FAST.OQ', 'Fastenal Co', 'NASDAQ'),
#  ('FCX.N', 'Freeport-McMoRan Inc', 'New York Stock Exchange'),
#  ('FDS.N', 'Factset Research Systems Inc', 'New York Stock Exchange'),
#  ('FDX.N', 'FedEx Corp', 'New York Stock Exchange'),
#  ('FE.N', 'FirstEnergy Corp', 'New York Stock Exchange'),
#  ('FER.MC', 'Ferrovial SE', 'Bolsa de Madrid'),
#  ('FFIV.OQ', 'F5 Inc', 'NASDAQ'),
#  ('FICO.N', 'Fair Isaac Corp', 'New York Stock Exchange'),
#  ('FIS.N',
#   'Fidelity National Information Services Inc',
#   'New York Stock Exchange'),
#  ('FISV.OQ', 'Fiserv Inc', 'NASDAQ'),
#  ('FITB.OQ', 'Fifth Third Bancorp', 'NASDAQ'),
#  ('FIX.N', 'Comfort Systems USA Inc', 'New York Stock Exchange'),
#  ('FMEG.DE', 'Fresenius Medical Care AG', 'Deutsche Börse (Frankfurt)'),
#  ('FND.N', 'Floor & Decor Holdings Inc', 'New York Stock Exchange'),
#  ('FOUG.PA', 'Eiffage SA', 'Euronext Paris'),
#  ('FOX.OQ', 'Fox Corp (Class B)', 'NASDAQ'),
#  ('FOXA.OQ', 'Fox Corp (Class A)', 'NASDAQ'),
#  ('FREG.DE', 'Fresenius SE & Co KGaA', 'Deutsche Börse (Frankfurt)'),
#  ('FRES.L', 'Fresnillo PLC', 'London Stock Exchange'),
#  ('FRO.N', 'Frontline Plc', 'New York Stock Exchange'),
#  ('FRT.N', 'Federal Realty Investment Trust', 'New York Stock Exchange'),
#  ('FSLR.OQ', 'First Solar Inc', 'NASDAQ'),
#  ('FTNT.OQ', 'Fortinet Inc', 'NASDAQ'),
#  ('FTV.N', 'Fortive Corp', 'New York Stock Exchange'),
#  ('G1AG.DE', 'GEA Group AG', 'Deutsche Börse (Frankfurt)'),
#  ('G24n.DE', 'Scout24 SE', 'Deutsche Börse (Frankfurt)'),
#  ('GAW.L', 'Games Workshop Group PLC', 'London Stock Exchange'),
#  ('GD.N', 'General Dynamics Corp', 'New York Stock Exchange'),
#  ('GDDY.N', 'GoDaddy Inc', 'New York Stock Exchange'),
#  ('GE.N', 'General Electric Co', 'New York Stock Exchange'),
#  ('GEHC.OQ', 'GE Healthcare Technologies Inc', 'NASDAQ'),
#  ('GEN.OQ', 'Gen Digital Inc', 'NASDAQ'),
#  ('GEV.N', 'GE Vernova Inc', 'New York Stock Exchange'),
#  ('GILD.OQ', 'Gilead Sciences Inc', 'NASDAQ'),
#  ('GIS.N', 'General Mills Inc', 'New York Stock Exchange'),
#  ('GL.N', 'Globe Life Inc', 'New York Stock Exchange'),
#  ('GLEN.L', 'Glencore PLC', 'London Stock Exchange'),
#  ('GLW.N', 'Corning Inc', 'New York Stock Exchange'),
#  ('GM.N', 'General Motors Co', 'New York Stock Exchange'),
#  ('GNK.N', 'Genco Shipping & Trading Ltd', 'New York Stock Exchange'),
#  ('GNRC.N', 'Generac Holdings Inc', 'New York Stock Exchange'),
#  ('GOOG.OQ', 'Alphabet Inc', 'NASDAQ'),
#  ('GOOGL.OQ', 'Alphabet Inc (Class A)', 'NASDAQ'),
#  ('GPC.N', 'Genuine Parts Co', 'New York Stock Exchange'),
#  ('GPN.N', 'Global Payments Inc', 'New York Stock Exchange'),
#  ('GRMN.N', 'Garmin Ltd', 'New York Stock Exchange'),
#  ('GS.N', 'Goldman Sachs Group Inc', 'New York Stock Exchange'),
#  ('GSK.L', 'GSK plc', 'London Stock Exchange'),
#  ('GWW.N', 'WW Grainger Inc', 'New York Stock Exchange'),
#  ('GXO.N', 'GXO Logistics Inc', 'New York Stock Exchange'),
#  ('HAL.N', 'Halliburton Co', 'New York Stock Exchange'),
#  ('HAS.OQ', 'Hasbro Inc', 'NASDAQ'),
#  ('HBAN.OQ', 'Huntington Bancshares Inc', 'NASDAQ'),
#  ('HCA.N', 'HCA Healthcare Inc', 'New York Stock Exchange'),
#  ('HD.N', 'Home Depot Inc', 'New York Stock Exchange'),
#  ('HEIG.DE', 'Heidelberg Materials AG', 'Deutsche Börse (Frankfurt)'),
#  ('HIG.N', 'Hartford Insurance Group Inc', 'New York Stock Exchange'),
#  ('HII.N', 'Huntington Ingalls Industries Inc', 'New York Stock Exchange'),
#  ('HIK.L', 'Hikma Pharmaceuticals PLC', 'London Stock Exchange'),
#  ('HLMA.L', 'Halma PLC', 'London Stock Exchange'),
#  ('HLN.L', 'Haleon PLC', 'London Stock Exchange'),
#  ('HLT.N', 'Hilton Worldwide Holdings Inc', 'New York Stock Exchange'),
#  ('HNKG_p.DE', 'Henkel AG & Co KGaA', 'Deutsche Börse (Frankfurt)'),
#  ('HNRGn.DE', 'Hannover Rueck SE', 'Deutsche Börse (Frankfurt)'),
#  ('HOLX.OQ', 'Hologic Inc', 'NASDAQ'),
#  ('HON.OQ', 'Honeywell International Inc', 'NASDAQ'),
#  ('HOOD.OQ', 'Robinhood Markets Inc', 'NASDAQ'),
#  ('HPE.N', 'Hewlett Packard Enterprise Co', 'New York Stock Exchange'),
#  ('HPQ.N', 'HP Inc', 'New York Stock Exchange'),
#  ('HRL.N', 'Hormel Foods Corp', 'New York Stock Exchange'),
#  ('HRMS.PA', 'Hermes International SCA', 'Euronext Paris'),
#  ('HSBA.L', 'HSBC Holdings PLC', 'London Stock Exchange'),
#  ('HSIC.OQ', 'Henry Schein Inc', 'NASDAQ'),
#  ('HST.OQ', 'Host Hotels & Resorts Inc', 'NASDAQ'),
#  ('HSX.L', 'Hiscox Ltd', 'London Stock Exchange'),
#  ('HSY.N', 'Hershey Co', 'New York Stock Exchange'),
#  ('HUBB.N', 'Hubbell Inc', 'New York Stock Exchange'),
#  ('HUBG.O', 'Hub Group Inc', 'NASDAQ'),
#  ('HUM.N', 'Humana Inc', 'New York Stock Exchange'),
#  ('HWDN.L', 'Howden Joinery Group PLC', 'London Stock Exchange'),
#  ('HWM.N', 'Howmet Aerospace Inc', 'New York Stock Exchange'),
#  ('IBE.MC', 'Iberdrola SA', 'Bolsa de Madrid'),
#  ('IBKR.OQ', 'Interactive Brokers Group Inc', 'NASDAQ'),
#  ('IBM.N', 'International Business Machines Corp', 'New York Stock Exchange'),
#  ('ICAG.L',
#   'International Consolidated Airlines Group SA',
#   'London Stock Exchange'),
#  ('ICE.N', 'Intercontinental Exchange Inc', 'New York Stock Exchange'),
#  ('ICGIN.L', 'ICG PLC', 'London Stock Exchange'),
#  ('IDXX.OQ', 'IDEXX Laboratories Inc', 'NASDAQ'),
#  ('IEX.N', 'IDEX Corp', 'New York Stock Exchange'),
#  ('IFF.N',
#   'International Flavors & Fragrances Inc',
#   'New York Stock Exchange'),
#  ('IFXGn.DE', 'Infineon Technologies AG', 'Deutsche Börse (Frankfurt)'),
#  ('IHG.L', 'InterContinental Hotels Group PLC', 'London Stock Exchange'),
#  ('III.L', '3i Group PLC', 'London Stock Exchange'),
#  ('IMB.L', 'Imperial Brands PLC', 'London Stock Exchange'),
#  ('IMI.L', 'IMI PLC', 'London Stock Exchange'),
#  ('INCY.OQ', 'Incyte Corp', 'NASDAQ'),
#  ('INF.L', 'Informa PLC', 'London Stock Exchange'),
#  ('INGA.AS', 'ING Groep NV', 'Euronext Amsterdam'),
#  ('INSM.OQ', 'Insmed Inc', 'NASDAQ'),
#  ('INSW.K', 'International Seaways Inc', 'New York Stock Exchange'),
#  ('INTC.OQ', 'Intel Corp', 'NASDAQ'),
#  ('INTU.OQ', 'Intuit Inc', 'NASDAQ'),
#  ('INVH.N', 'Invitation Homes Inc', 'New York Stock Exchange'),
#  ('IP.N', 'International Paper Co', 'New York Stock Exchange'),
#  ('IQV.N', 'IQVIA Holdings Inc', 'New York Stock Exchange'),
#  ('IR.N', 'Ingersoll Rand Inc', 'New York Stock Exchange'),
#  ('IRM.N', 'Iron Mountain Inc', 'New York Stock Exchange'),
#  ('ISP.MI', 'Intesa Sanpaolo SpA', 'Borsa Italiana (Milan)'),
#  ('ISRG.OQ', 'Intuitive Surgical Inc', 'NASDAQ'),
#  ('IT.N', 'Gartner Inc', 'New York Stock Exchange'),
#  ('ITRK.L', 'Intertek Group PLC', 'London Stock Exchange'),
#  ('ITW.N', 'Illinois Tool Works Inc', 'New York Stock Exchange'),
#  ('ITX.MC', 'Industria de Diseno Textil SA', 'Bolsa de Madrid'),
#  ('IVZ.N', 'Invesco Ltd', 'New York Stock Exchange'),
#  ('J.N', 'Jacobs Solutions Inc', 'New York Stock Exchange'),
#  ('JBHT.OQ', 'J B Hunt Transport Services Inc', 'NASDAQ'),
#  ('JBL.N', 'Jabil Inc', 'New York Stock Exchange'),
#  ('JCI.N', 'Johnson Controls International PLC', 'New York Stock Exchange'),
#  ('JD.L', 'JD Sports Fashion PLC', 'London Stock Exchange'),
#  ('JKHY.OQ', 'Jack Henry & Associates Inc', 'NASDAQ'),
#  ('JNJ.N', 'Johnson & Johnson', 'New York Stock Exchange'),
#  ('JPM.N', 'JPMorgan Chase & Co', 'New York Stock Exchange'),
#  ('KDP.OQ', 'Keurig Dr Pepper Inc', 'NASDAQ'),
#  ('KEX.N', 'Kirby Corp', 'New York Stock Exchange'),
#  ('KEY.N', 'KeyCorp', 'New York Stock Exchange'),
#  ('KEYS.N', 'Keysight Technologies Inc', 'New York Stock Exchange'),
#  ('KGF.L', 'Kingfisher PLC', 'London Stock Exchange'),
#  ('KHC.OQ', 'Kraft Heinz Co', 'NASDAQ'),
#  ('KIM.N', 'Kimco Realty Corp', 'New York Stock Exchange'),
#  ('KKR.N', 'KKR & Co Inc', 'New York Stock Exchange'),
#  ('KLAC.OQ', 'KLA Corp', 'NASDAQ'),
#  ('KMB.OQ', 'Kimberly-Clark Corp', 'NASDAQ'),
#  ('KMI.N', 'Kinder Morgan Inc', 'New York Stock Exchange'),
#  ('KO.N', 'Coca-Cola Co', 'New York Stock Exchange'),
#  ('KR.N', 'Kroger Co', 'New York Stock Exchange'),
#  ('KVUE.N', 'Kenvue Inc', 'New York Stock Exchange'),
#  ('L.N', 'Loews Corp', 'New York Stock Exchange'),
#  ('LAND.L', 'Land Securities Group PLC', 'London Stock Exchange'),
#  ('LDOS.N', 'Leidos Holdings Inc', 'New York Stock Exchange'),
#  ('LEGD.PA', 'Legrand SA', 'Euronext Paris'),
#  ('LEN.N', 'Lennar Corp', 'New York Stock Exchange'),
#  ('LGEN.L', 'Legal & General Group PLC', 'London Stock Exchange'),
#  ('LH.N', 'Labcorp Holdings Inc', 'New York Stock Exchange'),
#  ('LHX.N', 'L3Harris Technologies Inc', 'New York Stock Exchange'),
#  ('LII.N', 'Lennox International Inc', 'New York Stock Exchange'),
#  ('LIN.OQ', 'Linde PLC', 'NASDAQ'),
#  ('LLOY.L', 'Lloyds Banking Group PLC', 'London Stock Exchange'),
#  ('LLY.N', 'Eli Lilly and Co', 'New York Stock Exchange'),
#  ('LLYVK.OQ', 'Liberty Live Holdings Inc', 'NASDAQ'),
#  ('LMPL.L', 'LondonMetric Property PLC', 'London Stock Exchange'),
#  ('LMT.N', 'Lockheed Martin Corp', 'New York Stock Exchange'),
#  ('LNT.OQ', 'Alliant Energy Corp', 'NASDAQ'),
#  ('LOW.N', "Lowe's Companies Inc", 'New York Stock Exchange'),
#  ('LPX.N', 'Louisiana-Pacific Corp', 'New York Stock Exchange'),
#  ('LRCX.OQ', 'Lam Research Corp', 'NASDAQ'),
#  ('LSEG.L', 'London Stock Exchange Group PLC', 'London Stock Exchange'),
#  ('LSTR.O', 'Landstar System Inc', 'NASDAQ'),
#  ('LULU.OQ', 'Lululemon Athletica Inc', 'NASDAQ'),
#  ('LUV.N', 'Southwest Airlines Co', 'New York Stock Exchange'),
#  ('LVMH.PA', 'LVMH Moet Hennessy Louis Vuitton SE', 'Euronext Paris'),
#  ('LVS.N', 'Las Vegas Sands Corp', 'New York Stock Exchange'),
#  ('LW.N', 'Lamb Weston Holdings Inc', 'New York Stock Exchange'),
#  ('LYB.N', 'LyondellBasell Industries NV', 'New York Stock Exchange'),
#  ('LYV.N', 'Live Nation Entertainment Inc', 'New York Stock Exchange'),
#  ('MA.N', 'Mastercard Inc', 'New York Stock Exchange'),
#  ('MAA.N', 'Mid-America Apartment Communities Inc', 'New York Stock Exchange'),
#  ('MANH.O', 'Manhattan Associates Inc', 'NASDAQ'),
#  ('MAR.OQ', 'Marriott International Inc', 'NASDAQ'),
#  ('MAS.N', 'Masco Corp', 'New York Stock Exchange'),
#  ('MBGn.DE', 'Mercedes-Benz Group AG', 'Deutsche Börse (Frankfurt)'),
#  ('MCD.N', "McDonald's Corp", 'New York Stock Exchange'),
#  ('MCHP.OQ', 'Microchip Technology Inc', 'NASDAQ'),
#  ('MCK.N', 'McKesson Corp', 'New York Stock Exchange'),
#  ('MCO.N', "Moody's Corp", 'New York Stock Exchange'),
#  ('MDLZ.OQ', 'Mondelez International Inc', 'NASDAQ'),
#  ('MDT.N', 'Medtronic PLC', 'New York Stock Exchange'),
#  ('MELI.OQ', 'MercadoLibre Inc', 'NASDAQ'),
#  ('MET.N', 'MetLife Inc', 'New York Stock Exchange'),
#  ('META.OQ', 'Meta Platforms Inc', 'NASDAQ'),
#  ('MGM.N', 'MGM Resorts International', 'New York Stock Exchange'),
#  ('MICP.PA',
#   'Compagnie Generale des Etablissements Michelin SCA',
#   'Euronext Paris'),
#  ('MKC.N', 'McCormick & Company Inc', 'New York Stock Exchange'),
#  ('MKS.L', 'Marks and Spencer Group PLC', 'London Stock Exchange'),
#  ('MLM.N', 'Martin Marietta Materials Inc', 'New York Stock Exchange'),
#  ('MMM.N', '3M Co', 'New York Stock Exchange'),
#  ('MNDI.L', 'Mondi PLC', 'London Stock Exchange'),
#  ('MNG.L', 'M&G PLC', 'London Stock Exchange'),
#  ('MNST.OQ', 'Monster Beverage Corp', 'NASDAQ'),
#  ('MO.N', 'Altria Group Inc', 'New York Stock Exchange'),
#  ('MOH.N', 'Molina Healthcare Inc', 'New York Stock Exchange'),
#  ('MOS.N', 'Mosaic Co', 'New York Stock Exchange'),
#  ('MPC.N', 'Marathon Petroleum Corp', 'New York Stock Exchange'),
#  ('MPWR.OQ', 'Monolithic Power Systems Inc', 'NASDAQ'),
#  ('MRCG.DE', 'Merck KGaA', 'Deutsche Börse (Frankfurt)'),
#  ('MRK.N', 'Merck & Co Inc', 'New York Stock Exchange'),
#  ('MRNA.OQ', 'Moderna Inc', 'NASDAQ'),
#  ('MRON.L', 'Melrose Industries PLC', 'London Stock Exchange'),
#  ('MRSH.N', 'Marsh & McLennan Companies Inc', 'New York Stock Exchange'),
#  ('MRVL.OQ', 'Marvell Technology Inc', 'NASDAQ'),
#  ('MS.N', 'Morgan Stanley', 'New York Stock Exchange'),
#  ('MSCI.N', 'MSCI Inc', 'New York Stock Exchange'),
#  ('MSFT.OQ', 'Microsoft Corp', 'NASDAQ'),
#  ('MSI.N', 'Motorola Solutions Inc', 'New York Stock Exchange'),
#  ('MSTR.OQ', 'Strategy Inc', 'NASDAQ'),
#  ('MT.AS', 'ArcelorMittal SA', 'Euronext Amsterdam'),
#  ('MTB.N', 'M&T Bank Corp', 'New York Stock Exchange'),
#  ('MTCH.OQ', 'Match Group Inc', 'NASDAQ'),
#  ('MTD.N', 'Mettler-Toledo International Inc', 'New York Stock Exchange'),
#  ('MTLN.L', 'Metlen Energy & Metals PLC', 'London Stock Exchange'),
#  ('MTXGn.DE', 'MTU Aero Engines AG', 'Deutsche Börse (Frankfurt)'),
#  ('MU.OQ', 'Micron Technology Inc', 'NASDAQ'),
#  ('MUVGn.DE',
#   'Muenchener Rueckversicherungs-Gesellschaft in Muenchen AG',
#   'Deutsche Börse (Frankfurt)'),
#  ('NCLH.N', 'Norwegian Cruise Line Holdings Ltd', 'New York Stock Exchange'),
#  ('NDAFI.HE', 'Nordea Bank Abp', 'Nasdaq Helsinki'),
#  ('NDAQ.OQ', 'Nasdaq Inc', 'NASDAQ'),
#  ('NDSN.OQ', 'Nordson Corp', 'NASDAQ'),
#  ('NEE.N', 'Nextera Energy Inc', 'New York Stock Exchange'),
#  ('NEM.N', 'Newmont Corporation', 'New York Stock Exchange'),
#  ('NFLX.OQ', 'Netflix Inc', 'NASDAQ'),
#  ('NG.L', 'National Grid PLC', 'London Stock Exchange'),
#  ('NI.N', 'NiSource Inc', 'New York Stock Exchange'),
#  ('NKE.N', 'Nike Inc', 'New York Stock Exchange'),
#  ('NOC.N', 'Northrop Grumman Corp', 'New York Stock Exchange'),
#  ('NOW.N', 'ServiceNow Inc', 'New York Stock Exchange'),
#  ('NRG.N', 'NRG Energy Inc', 'New York Stock Exchange'),
#  ('NSC.N', 'Norfolk Southern Corp', 'New York Stock Exchange'),
#  ('NTAP.OQ', 'NetApp Inc', 'NASDAQ'),
#  ('NTRS.OQ', 'Northern Trust Corp', 'NASDAQ'),
#  ('NU.N', 'Nu Holdings Ltd', 'New York Stock Exchange'),
#  ('NUE.N', 'Nucor Corp', 'New York Stock Exchange'),
#  ('NVDA.OQ', 'NVIDIA Corp', 'NASDAQ'),
#  ('NVR.N', 'NVR Inc', 'New York Stock Exchange'),
#  ('NWG.L', 'NatWest Group PLC', 'London Stock Exchange'),
#  ('NWS.OQ', 'News Corp (Class B)', 'NASDAQ'),
#  ('NWSA.OQ', 'News Corp (Class A)', 'NASDAQ'),
#  ('NXPI.OQ', 'NXP Semiconductors NV', 'NASDAQ'),
#  ('NXT.L', 'Next PLC', 'London Stock Exchange'),
#  ('O.N', 'Realty Income Corp', 'New York Stock Exchange'),
#  ('ODFL.OQ', 'Old Dominion Freight Line Inc', 'NASDAQ'),
#  ('OKE.N', 'ONEOK Inc', 'New York Stock Exchange'),
#  ('OMC.N', 'Omnicom Group Inc', 'New York Stock Exchange'),
#  ('ON.OQ', 'ON Semiconductor Corp', 'NASDAQ'),
#  ('ORAN.PA', 'Orange SA', 'Euronext Paris'),
#  ('ORCL.N', 'Oracle Corp', 'New York Stock Exchange'),
#  ('OREP.PA', "L'Oreal SA", 'Euronext Paris'),
#  ('ORLY.OQ', "O'Reilly Automotive Inc", 'NASDAQ'),
#  ('OTIS.N', 'Otis Worldwide Corp', 'New York Stock Exchange'),
#  ('OXY.N', 'Occidental Petroleum Corp', 'New York Stock Exchange'),
#  ('PANW.OQ', 'Palo Alto Networks Inc', 'NASDAQ'),
#  ('PAYC.N', 'Paycom Software Inc', 'New York Stock Exchange'),
#  ('PAYX.OQ', 'Paychex Inc', 'NASDAQ'),
#  ('PCAR.OQ', 'Paccar Inc', 'NASDAQ'),
#  ('PCG.N', 'PG&E Corp', 'New York Stock Exchange'),
#  ('PDD.OQ', 'PDD Holdings Inc', 'NASDAQ'),
#  ('PEG.N', 'Public Service Enterprise Group Inc', 'New York Stock Exchange'),
#  ('PEP.OQ', 'PepsiCo Inc', 'NASDAQ'),
#  ('PERP.PA', 'Pernod Ricard SA', 'Euronext Paris'),
#  ('PFE.N', 'Pfizer Inc', 'New York Stock Exchange'),
#  ('PFG.OQ', 'Principal Financial Group Inc', 'NASDAQ'),
#  ('PG.N', 'Procter & Gamble Co', 'New York Stock Exchange'),
#  ('PGR.N', 'Progressive Corp', 'New York Stock Exchange'),
#  ('PH.N', 'Parker-Hannifin Corp', 'New York Stock Exchange'),
#  ('PHM.N', 'Pultegroup Inc', 'New York Stock Exchange'),
#  ('PHNX.L', 'Phoenix Group Holdings PLC', 'London Stock Exchange'),
#  ('PKG.N', 'Packaging Corp of America', 'New York Stock Exchange'),
#  ('PLD.N', 'Prologis Inc', 'New York Stock Exchange'),
#  ('PLTR.OQ', 'Palantir Technologies Inc', 'NASDAQ'),
#  ('PM.N', 'Philip Morris International Inc', 'New York Stock Exchange'),
#  ('PNC.N', 'PNC Financial Services Group Inc', 'New York Stock Exchange'),
#  ('PNR.N', 'Pentair PLC', 'New York Stock Exchange'),
#  ('PNW.N', 'Pinnacle West Capital Corp', 'New York Stock Exchange'),
#  ('PODD.OQ', 'Insulet Corp', 'NASDAQ'),
#  ('POOL.OQ', 'Pool Corp', 'NASDAQ'),
#  ('PPG.N', 'PPG Industries Inc', 'New York Stock Exchange'),
#  ('PPL.N', 'PPL Corp', 'New York Stock Exchange'),
#  ('PRTP.PA', 'Kering SA', 'Euronext Paris'),
#  ('PRU.L', 'Prudential PLC', 'London Stock Exchange'),
#  ('PRU.N', 'Prudential Financial Inc', 'New York Stock Exchange'),
#  ('PRX.AS', 'Prosus NV', 'Euronext Amsterdam'),
#  ('PSA.N', 'Public Storage', 'New York Stock Exchange'),
#  ('PSHG_p.DE', 'Porsche Automobil Holding SE', 'Deutsche Börse (Frankfurt)'),
#  ('PSKY.OQ', 'Paramount Skydance Corp', 'NASDAQ'),
#  ('PSN.L', 'Persimmon PLC', 'London Stock Exchange'),
#  ('PSON.L', 'Pearson PLC', 'London Stock Exchange'),
#  ('PSX.N', 'Phillips 66', 'New York Stock Exchange'),
#  ('PTC.OQ', 'PTC Inc', 'NASDAQ'),
#  ('PUBP.PA', 'Publicis Groupe SA', 'Euronext Paris'),
#  ('PWR.N', 'Quanta Services Inc', 'New York Stock Exchange'),
#  ('PYPL.OQ', 'PayPal Holdings Inc', 'NASDAQ'),
#  ('Q.N', 'Qnity Electronics Inc', 'New York Stock Exchange'),
#  ('QCOM.OQ', 'Qualcomm Inc', 'NASDAQ'),
#  ('QIA.DE', 'Qiagen NV', 'Deutsche Börse (Frankfurt)'),
#  ('R.N', 'Ryder System Inc', 'New York Stock Exchange'),
#  ('RACE.MI', 'Ferrari NV', 'Borsa Italiana (Milan)'),
#  ('RCL.N', 'Royal Caribbean Cruises Ltd', 'New York Stock Exchange'),
#  ('REG.OQ', 'Regency Centers Corp', 'NASDAQ'),
#  ('REGN.OQ', 'Regeneron Pharmaceuticals Inc', 'NASDAQ'),
#  ('REL.L', 'RELX PLC', 'London Stock Exchange'),
#  ('RENA.PA', 'Renault SA', 'Euronext Paris'),
#  ('RF.N', 'Regions Financial Corp', 'New York Stock Exchange'),
#  ('RHMG.DE', 'Rheinmetall AG', 'Deutsche Börse (Frankfurt)'),
#  ('RIO.L', 'Rio Tinto PLC', 'London Stock Exchange'),
#  ('RJF.N', 'Raymond James Financial Inc', 'New York Stock Exchange'),
#  ('RKT.L', 'Reckitt Benckiser Group PLC', 'London Stock Exchange'),
#  ('RL.N', 'Ralph Lauren Corp', 'New York Stock Exchange'),
#  ('RMD.N', 'Resmed Inc', 'New York Stock Exchange'),
#  ('RMV.L', 'Rightmove PLC', 'London Stock Exchange'),
#  ('ROK.N', 'Rockwell Automation Inc', 'New York Stock Exchange'),
#  ('ROL.N', 'Rollins Inc', 'New York Stock Exchange'),
#  ('ROP.OQ', 'Roper Technologies Inc', 'NASDAQ'),
#  ('ROST.OQ', 'Ross Stores Inc', 'NASDAQ'),
#  ('RR.L', 'Rolls-Royce Holdings PLC', 'London Stock Exchange'),
#  ('RSG.N', 'Republic Services Inc', 'New York Stock Exchange'),
#  ('RTO.L', 'Rentokil Initial PLC', 'London Stock Exchange'),
#  ('RTX.N', 'RTX Corp', 'New York Stock Exchange'),
#  ('RVTY.N', 'Revvity Inc', 'New York Stock Exchange'),
#  ('RWEG.DE', 'RWE AG', 'Deutsche Börse (Frankfurt)'),
#  ('SAF.PA', 'Safran SA', 'Euronext Paris'),
#  ('SAIA.OQ', 'Saia Inc', 'NASDAQ'),
#  ('SAN.MC', 'Banco Santander SA', 'Bolsa de Madrid'),
#  ('SAPG.DE', 'SAP SE', 'Deutsche Börse (Frankfurt)'),
#  ('SASY.PA', 'Sanofi SA', 'Euronext Paris'),
#  ('SBAC.OQ', 'SBA Communications Corp', 'NASDAQ'),
#  ('SBLK.O', 'Star Bulk Carriers Corp', 'NASDAQ'),
#  ('SBRY.L', 'J Sainsbury PLC', 'London Stock Exchange'),
#  ('SBUX.OQ', 'Starbucks Corp', 'NASDAQ'),
#  ('SCHN.PA', 'Schneider Electric SE', 'Euronext Paris'),
#  ('SCHW.N', 'Charles Schwab Corp', 'New York Stock Exchange'),
#  ('SDR.L', 'Schroders PLC', 'London Stock Exchange'),
#  ('SGE.L', 'Sage Group PLC', 'London Stock Exchange'),
#  ('SGEF.PA', 'Vinci SA', 'Euronext Paris'),
#  ('SGOB.PA', 'Compagnie de Saint Gobain SA', 'Euronext Paris'),
#  ('SGRO.L', 'SEGRO PLC', 'London Stock Exchange'),
#  ('SHEL.L', 'Shell PLC', 'London Stock Exchange'),
#  ('SHLG.DE', 'Siemens Healthineers AG', 'Deutsche Börse (Frankfurt)'),
#  ('SHOP.OQ', 'Shopify Inc', 'NASDAQ'),
#  ('SHW.N', 'Sherwin-Williams Co', 'New York Stock Exchange'),
#  ('SIEGn.DE', 'Siemens AG', 'Deutsche Börse (Frankfurt)'),
#  ('SIRI.O', 'Sirius XM Holdings Inc', 'NASDAQ'),
#  ('SJM.N', 'J M Smucker Co', 'New York Stock Exchange'),
#  ('SJP.L', "St James's Place PLC", 'London Stock Exchange'),
#  ('SLB.N', 'Slb NV', 'New York Stock Exchange'),
#  ('SMCI.OQ', 'Super Micro Computer Inc', 'NASDAQ'),
#  ('SMIN.L', 'Smiths Group PLC', 'London Stock Exchange'),
#  ('SN.L', 'Smith & Nephew PLC', 'London Stock Exchange'),
#  ('SNA.N', 'Snap-On Inc', 'New York Stock Exchange'),
#  ('SNDK.OQ', 'Sandisk Corp', 'NASDAQ'),
#  ('SNOW.K', 'Snowflake Inc', 'New York Stock Exchange'),
#  ('SNPS.OQ', 'Synopsys Inc', 'NASDAQ'),
#  ('SO.N', 'Southern Co', 'New York Stock Exchange'),
#  ('SOGN.PA', 'Societe Generale SA', 'Euronext Paris'),
#  ('SOLB.BR', 'Solvay SA', 'Euronext Brussels'),
#  ('SOLV.N', 'Solventum Corp', 'New York Stock Exchange'),
#  ('SPG.N', 'Simon Property Group Inc', 'New York Stock Exchange'),
#  ('SPGI.N', 'S&P Global Inc', 'New York Stock Exchange'),
#  ('SPX.L', 'Spirax Group PLC', 'London Stock Exchange'),
#  ('SRE.N', 'Sempra', 'New York Stock Exchange'),
#  ('SSE.L', 'SSE PLC', 'London Stock Exchange'),
#  ('STAN.L', 'Standard Chartered PLC', 'London Stock Exchange'),
#  ('STE.N', 'STERIS plc', 'New York Stock Exchange'),
#  ('STLAM.MI', 'Stellantis NV', 'Borsa Italiana (Milan)'),
#  ('STLD.OQ', 'Steel Dynamics Inc', 'NASDAQ'),
#  ('STMMI.MI', 'STMicroelectronics NV', 'Borsa Italiana (Milan)'),
#  ('STT.N', 'State Street Corp', 'New York Stock Exchange'),
#  ('STX.OQ', 'Seagate Technology Holdings PLC', 'NASDAQ'),
#  ('STZ.N', 'Constellation Brands Inc', 'New York Stock Exchange'),
#  ('SVT.L', 'Severn Trent PLC', 'London Stock Exchange'),
#  ('SW.N', 'Smurfit WestRock PLC', 'New York Stock Exchange'),
#  ('SWK.N', 'Stanley Black & Decker Inc', 'New York Stock Exchange'),
#  ('SWKS.OQ', 'Skyworks Solutions Inc', 'NASDAQ'),
#  ('SY1G.DE', 'Symrise AG', 'Deutsche Börse (Frankfurt)'),
#  ('SYF.N', 'Synchrony Financial', 'New York Stock Exchange'),
#  ('SYK.N', 'Stryker Corp', 'New York Stock Exchange'),
#  ('SYY.N', 'Sysco Corp', 'New York Stock Exchange'),
#  ('T.N', 'AT&T Inc', 'New York Stock Exchange'),
#  ('TAP.N', 'Molson Coors Beverage Co', 'New York Stock Exchange'),
#  ('TCFP.PA', 'Thales SA', 'Euronext Paris'),
#  ('TDG.N', 'TransDigm Group Inc', 'New York Stock Exchange'),
#  ('TDY.N', 'Teledyne Technologies Inc', 'New York Stock Exchange'),
#  ('TEAM.OQ', 'Atlassian Corp', 'NASDAQ'),
#  ('TECH.OQ', 'Bio-Techne Corp', 'NASDAQ'),
#  ('TEL.N', 'TE Connectivity PLC', 'New York Stock Exchange'),
#  ('TER.OQ', 'Teradyne Inc', 'NASDAQ'),
#  ('TFC.N', 'Truist Financial Corp', 'New York Stock Exchange'),
#  ('TGT.N', 'Target Corp', 'New York Stock Exchange'),
#  ('TJX.N', 'TJX Companies Inc', 'New York Stock Exchange'),
#  ('TKO.N', 'TKO Group Holdings Inc', 'New York Stock Exchange'),
#  ('TMO.N', 'Thermo Fisher Scientific Inc', 'New York Stock Exchange'),
#  ('TMUS.OQ', 'T-Mobile US Inc', 'NASDAQ'),
#  ('TPL.N', 'Texas Pacific Land Corp', 'New York Stock Exchange'),
#  ('TPR.N', 'Tapestry Inc', 'New York Stock Exchange'),
#  ('TRGP.N', 'Targa Resources Corp', 'New York Stock Exchange'),
#  ('TRI.TO', 'Thomson Reuters Corp', 'Toronto Stock Exchange'),
#  ('TRMB.OQ', 'Trimble Inc', 'NASDAQ'),
#  ('TROW.OQ', 'T Rowe Price Group Inc', 'NASDAQ'),
#  ('TRV.N', 'Travelers Companies Inc', 'New York Stock Exchange'),
#  ('TSCO.L', 'Tesco PLC', 'London Stock Exchange'),
#  ('TSCO.OQ', 'Tractor Supply Co', 'NASDAQ'),
#  ('TSLA.OQ', 'Tesla Inc', 'NASDAQ'),
#  ('TSM.N',
#   'Taiwan Semiconductor Manufacturing Co Ltd',
#   'New York Stock Exchange'),
#  ('TSN.N', 'Tyson Foods Inc', 'New York Stock Exchange'),
#  ('TT.N', 'Trane Technologies PLC', 'New York Stock Exchange'),
#  ('TTD.OQ', 'Trade Desk Inc', 'NASDAQ'),
#  ('TTEF.PA', 'TotalEnergies SE', 'Euronext Paris'),
#  ('TTWO.OQ', 'Take-Two Interactive Software Inc', 'NASDAQ'),
#  ('TXN.OQ', 'Texas Instruments Inc', 'NASDAQ'),
#  ('TXT.N', 'Textron Inc', 'New York Stock Exchange'),
#  ('TYL.N', 'Tyler Technologies Inc', 'New York Stock Exchange'),
#  ('UAL.OQ', 'United Airlines Holdings Inc', 'NASDAQ'),
#  ('UBER.N', 'Uber Technologies Inc', 'New York Stock Exchange'),
#  ('UBSG.S', 'UBS Group AG', 'SIX Swiss Exchange'),
#  ('UDR.N', 'UDR Inc', 'New York Stock Exchange'),
#  ('UHS.N', 'Universal Health Services Inc', 'New York Stock Exchange'),
#  ('ULTA.OQ', 'Ulta Beauty Inc', 'NASDAQ'),
#  ('ULVR.L', 'Unilever PLC', 'London Stock Exchange'),
#  ('UNH.N', 'UnitedHealth Group Inc', 'New York Stock Exchange'),
#  ('UNP.N', 'Union Pacific Corp', 'New York Stock Exchange'),
#  ('UPS.N', 'United Parcel Service Inc', 'New York Stock Exchange'),
#  ('URI.N', 'United Rentals Inc', 'New York Stock Exchange'),
#  ('URW.PA', 'Unibail-Rodamco-Westfield SE', 'Euronext Paris'),
#  ('USB.N', 'US Bancorp', 'New York Stock Exchange'),
#  ('UU.L', 'United Utilities Group PLC', 'London Stock Exchange'),
#  ('V.N', 'Visa Inc', 'New York Stock Exchange'),
#  ('VICI.N', 'VICI Properties Inc', 'New York Stock Exchange'),
#  ('VIE.PA', 'Veolia Environnement SA', 'Euronext Paris'),
#  ('VLO.N', 'Valero Energy Corp', 'New York Stock Exchange'),
#  ('VLTO.N', 'Veralto Corp', 'New York Stock Exchange'),
#  ('VMC.N', 'Vulcan Materials Co', 'New York Stock Exchange'),
#  ('VNAn.DE', 'Vonovia SE', 'Deutsche Börse (Frankfurt)'),
#  ('VOD.L', 'Vodafone Group PLC', 'London Stock Exchange'),
#  ('VOWG_p.DE', 'Volkswagen AG', 'Deutsche Börse (Frankfurt)'),
#  ('VRSK.OQ', 'Verisk Analytics Inc', 'NASDAQ'),
#  ('VRSN.OQ', 'VeriSign, Inc', 'NASDAQ'),
#  ('VRTX.OQ', 'Vertex Pharmaceuticals Inc', 'NASDAQ'),
#  ('VST.N', 'Vistra Corp', 'New York Stock Exchange'),
#  ('VTR.N', 'Ventas Inc', 'New York Stock Exchange'),
#  ('VTRS.OQ', 'Viatris Inc', 'NASDAQ'),
#  ('VZ.N', 'Verizon Communications Inc', 'New York Stock Exchange'),
#  ('WAB.N',
#   'Westinghouse Air Brake Technologies Corp',
#   'New York Stock Exchange'),
#  ('WAT.N', 'Waters Corp', 'New York Stock Exchange'),
#  ('WBD.OQ', 'Warner Bros Discovery Inc', 'NASDAQ'),
#  ('WDAY.OQ', 'Workday Inc', 'NASDAQ'),
#  ('WDC.OQ', 'Western Digital Corp', 'NASDAQ'),
#  ('WEC.N', 'WEC Energy Group Inc', 'New York Stock Exchange'),
#  ('WEIR.L', 'Weir Group PLC', 'London Stock Exchange'),
#  ('WELL.N', 'Welltower Inc', 'New York Stock Exchange'),
#  ('WFC.N', 'Wells Fargo & Co', 'New York Stock Exchange'),
#  ('WLSNc.AS', 'Wolters Kluwer NV', 'Euronext Amsterdam'),
#  ('WM.N', 'Waste Management Inc', 'New York Stock Exchange'),
#  ('WMB.N', 'Williams Companies Inc', 'New York Stock Exchange'),
#  ('WMT.OQ', 'Walmart Inc', 'NASDAQ'),
#  ('WRB.N', 'W R Berkley Corp', 'New York Stock Exchange'),
#  ('WSM.N', 'Williams-Sonoma Inc', 'New York Stock Exchange'),
#  ('WST.N', 'West Pharmaceutical Services Inc', 'New York Stock Exchange'),
#  ('WTB.L', 'Whitbread PLC', 'London Stock Exchange'),
#  ('WTW.OQ', 'Willis Towers Watson PLC', 'NASDAQ'),
#  ('WY.N', 'Weyerhaeuser Co', 'New York Stock Exchange'),
#  ('WYNN.OQ', 'Wynn Resorts Ltd', 'NASDAQ'),
#  ('XEL.OQ', 'Xcel Energy Inc', 'NASDAQ'),
#  ('XOM.N', 'Exxon Mobil Corp', 'New York Stock Exchange'),
#  ('XYL.N', 'Xylem Inc', 'New York Stock Exchange'),
#  ('XYZ.N', 'Block Inc', 'New York Stock Exchange'),
#  ('YUM.N', 'Yum! Brands Inc', 'New York Stock Exchange'),
#  ('ZALG.DE', 'Zalando SE', 'Deutsche Börse (Frankfurt)'),
#  ('ZBH.N', 'Zimmer Biomet Holdings Inc', 'New York Stock Exchange'),
#  ('ZBRA.OQ', 'Zebra Technologies Corp', 'NASDAQ'),
#  ('ZS.OQ', 'Zscaler Inc', 'NASDAQ'),
#  ('ZTS.N', 'Zoetis Inc', 'New York Stock Exchange')]

# %%
def prep_tuple_list(tuples: list[tuple[str, str, str]]) -> str:
    return ",".join(
        [
        f'("{ric}" - "{company}" - "{exchange}")'
         for ric, company, exchange in tuples
        ]
    )

yfinance_tickers = []

# Limit processed at a time to avoid context length issues
max_batch_size = 25
for i in range(0, len(firm_exchange), max_batch_size):
    batch = firm_exchange[i:min(i+max_batch_size, len(firm_exchange))]
    batch_size = len(batch)
    user_content = prep_tuple_list(batch)

    class IntendedResult(BaseModel):
        tickers: list[str] | None = Field(min_length=batch_size, max_length=batch_size)

    system_prompt = (
        "You will be provided a list of tuples representing a refinitiv RIC, "
        "company, and exchange as such: ('RIC' - 'Company Name' - 'Exchange Name'), "
        "('RIC' - 'Company Name' - 'Exchange Name'), ... "
        "\nYou must return a vector of corresponding yahoo finance tickers."
    )

    response = client.chat.completions.parse(
        model="gpt-5-nano",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_content},
        ],
        response_format=IntendedResult,  # Enforce structured output
    )

    parsed = response.choices[0].message.parsed
    if parsed and parsed.tickers:
        yfinance_tickers.extend(parsed.tickers)
        print(
            f"Added {len(parsed.tickers)} tickers"
            f"({len(yfinance_tickers)/len(firm_exchange):.2%})"
        )
    else:
        print("No tickers returned for this batch.")
# Out:
# Added 25 tickers(3.42%)
# Added 25 tickers(6.83%)
# Added 25 tickers(10.25%)
# Added 25 tickers(13.66%)
# Added 25 tickers(17.08%)
# Added 25 tickers(20.49%)
# Added 25 tickers(23.91%)
# Added 25 tickers(27.32%)
# Added 25 tickers(30.74%)
# Added 25 tickers(34.15%)
# Added 25 tickers(37.57%)
# Added 25 tickers(40.98%)
# Added 25 tickers(44.40%)
# Added 25 tickers(47.81%)
# Added 25 tickers(51.23%)
# Added 25 tickers(54.64%)
# Added 25 tickers(58.06%)
# Added 25 tickers(61.48%)
# Added 25 tickers(64.89%)
# Added 25 tickers(68.31%)
# Added 25 tickers(71.72%)
# Added 25 tickers(75.14%)
# Added 25 tickers(78.55%)
# Added 25 tickers(81.97%)
# Added 25 tickers(85.38%)
# Added 25 tickers(88.80%)
# Added 25 tickers(92.21%)
# Added 25 tickers(95.63%)
# Added 25 tickers(99.04%)
# Added 7 tickers(100.00%)

# %%
equities['yfinance_ticker'] = yfinance_tickers

# %%
lseg_prices = rd.get_history(
    universe=equities['Instrument'].tolist(),
    fields=['TR.PriceClose'],
    start='2026-02-01',
    end='2026-02-05',
)
# Out:
# /Users/cedricmckeever/projects/fin_db/.venv/lib/python3.12/site-packages/refinitiv/data/_tools/_dataframe.py:177:FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
# Make numeric
equities['lseg_valid'] = pd.to_numeric(
    equities['Instrument'].map(lseg_prices.transpose()['2026-02-03']),
    errors='coerce'
)

# %%
# Retrieve price from yfinance to compare
yfin = equities['yfinance_ticker'].to_list()

retrievals = []

# Limit tickers to stay safe
size = 25
for i in range(0, len(yfin), size):
    batch = yfin[i:min(i+size, len(yfin))]
    prices = yf.download(
        tickers=batch,
        start='2026-02-01',
        end='2026-02-05',
    )
    close = prices.xs('Close', axis=1, level=0)
    retrievals.append(close)
    time.sleep(1)  # Be nice to Yahoo's servers

yfin_prices = pd.concat(retrievals, axis=1)
# Out:
# [*********************100%***********************]  25 of 25 completed
# [**********************88%*****************      ]  22 of 25 completed$AIRP.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*********************100%***********************]  25 of 25 completed
#
# 1 Failed download:
# ['AIRP.PA']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*****************     36%                       ]  9 of 25 completed$AUTOA.L: possibly delisted; no timezone found
# [*******************   40%                       ]  10 of 25 completed$AXA.PA: possibly delisted; no timezone found
# [*********************100%***********************]  25 of 25 completed
#
# 2 Failed downloads:
# ['AUTOA.L', 'AXA.PA']: possibly delisted; no timezone found
# [*******************   40%                       ]  10 of 25 completed$BLL: possibly delisted; no timezone found
# [**********************64%******                 ]  16 of 25 completed$BF.B: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************84%***************        ]  21 of 25 completed$BKGH.L: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*********************100%***********************]  25 of 25 completed
#
# 3 Failed downloads:
# ['BLL']: possibly delisted; no timezone found
# ['BF.B', 'BKGH.L']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*******************   40%                       ]  10 of 25 completed$CAGR.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************60%****                   ]  15 of 25 completed$BOUY.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************84%***************        ]  21 of 25 completed$BT.L: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************92%*******************    ]  23 of 25 completed$BNRG.DE: possibly delisted; no timezone found
# [*********************100%***********************]  24 of 25 completed
#
# 4 Failed downloads:
# [*********************100%***********************]  24 of 25 completed['CAGR.PA', 'BOUY.PA', 'BT.L']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# ['BNRG.DE']: possibly delisted; no timezone found
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [**********************80%*************          ]  20 of 25 completed$DANO.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************84%***************        ]  21 of 25 completed$DB1G.DE: possibly delisted; no timezone found
# [**********************88%*****************      ]  22 of 25 completed$DAST.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*********************100%***********************]  25 of 25 completed
#
# 3 Failed downloads:
# ['DANO.PA', 'DAST.PA']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# ['DB1G.DE']: possibly delisted; no timezone found
# [********              16%                       ]  4 of 25 completed$DPL.L: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*******************   40%                       ]  10 of 25 completed$DPW.DE: possibly delisted; no timezone found
# [**********************88%*****************      ]  22 of 25 completed$PEAK: possibly delisted; no timezone found
# [*********************100%***********************]  25 of 25 completed
#
# 3 Failed downloads:
# ['DPL.L']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# ['DPW.DE', 'PEAK']: possibly delisted; no timezone found
# [**********************88%*****************      ]  22 of 25 completed$ESLX.PA: possibly delisted; no timezone found
# [*********************100%***********************]  25 of 25 completed
#
# 1 Failed download:
# ['ESLX.PA']: possibly delisted; no timezone found
# [**********************80%*************          ]  20 of 25 completed$EUFI.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*********************100%***********************]  25 of 25 completed
#
# 1 Failed download:
# ['EUFI.PA']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*****************     36%                       ]  9 of 25 completed$FOUG.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************72%**********             ]  18 of 25 completed$G24N.DE: possibly delisted; no timezone found
# [**********************76%***********            ]  19 of 25 completed$FREG.DE: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************80%*************          ]  20 of 25 completed$FMEG.DE: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************88%*****************      ]  22 of 25 completed$GEA.DE: possibly delisted; no timezone found
# [*********************100%***********************]  25 of 25 completed
#
# 5 Failed downloads:
# ['FOUG.PA', 'FREG.DE', 'FMEG.DE']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# ['G24N.DE', 'GEA.DE']: possibly delisted; no timezone found
# [*********************100%***********************]  25 of 25 completed
# [*******************   40%                       ]  10 of 25 completed$HRMS.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************84%***************        ]  21 of 25 completed$HNRG.DE: possibly delisted; no timezone found
# [**********************88%*****************      ]  22 of 25 completed$HNKG.DE: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*********************100%***********************]  25 of 25 completed
#
# 3 Failed downloads:
# ['HRMS.PA', 'HNKG.DE']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# ['HNRG.DE']: possibly delisted; no timezone found
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*******************   40%                       ]  10 of 25 completed$LEGD.PA: possibly delisted; no timezone found
# [********************* 44%                       ]  11 of 25 completed$LVMH.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************92%*******************    ]  23 of 25 completed$LLYVK.OQ: possibly delisted; no timezone found
# [*********************100%***********************]  24 of 25 completed
#
# 3 Failed downloads:
# ['LEGD.PA', 'LLYVK.OQ']: possibly delisted; no timezone found
# ['LVMH.PA']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*******************   40%                       ]  10 of 25 completed$MICP.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*********************100%***********************]  25 of 25 completed
#
# 1 Failed download:
# ['MICP.PA']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*******************   40%                       ]  10 of 25 completed$MRCG.DE: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************92%*******************    ]  23 of 25 completed$MRON.L: possibly delisted; no timezone found
# [*********************100%***********************]  25 of 25 completed
#
# 2 Failed downloads:
# ['MRCG.DE']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# ['MRON.L']: possibly delisted; no timezone found
# [*******************   40%                       ]  10 of 25 completed$NDAFI.HE: possibly delisted; no timezone found
# [*********************100%***********************]  25 of 25 completed
#
# 1 Failed download:
# ['NDAFI.HE']: possibly delisted; no timezone found
# [**********************84%***************        ]  21 of 25 completed$PERP.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************92%*******************    ]  23 of 25 completed$ORAN.PA: possibly delisted; no timezone found
# [*********************100%***********************]  25 of 25 completed
#
# 2 Failed downloads:
# ['PERP.PA']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# ['ORAN.PA']: possibly delisted; no timezone found
# [***************       32%                       ]  8 of 25 completed$PRTP.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************92%*******************    ]  23 of 25 completed$PSHG.DE: possibly delisted; no timezone found
# [*********************100%***********************]  25 of 25 completed
#
# 2 Failed downloads:
# ['PRTP.PA']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# ['PSHG.DE']: possibly delisted; no timezone found
# [*******************   40%                       ]  10 of 25 completed$PUBP.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# $RENA.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************84%***************        ]  21 of 25 completed$RB.L: possibly delisted; no timezone found
# [*********************100%***********************]  25 of 25 completed
#
# 3 Failed downloads:
# ['PUBP.PA', 'RENA.PA']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# ['RB.L']: possibly delisted; no timezone found
# [***************       32%                       ]  8 of 25 completed$SGOB.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*****************     36%                       ]  9 of 25 completed$SCHN.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*******************   40%                       ]  10 of 25 completed$SASY.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*********************100%***********************]  25 of 25 completed
#
# 3 Failed downloads:
# ['SGOB.PA', 'SCHN.PA', 'SASY.PA']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*****************     36%                       ]  9 of 25 completed$SOGN.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*******************   40%                       ]  10 of 25 completed$SJP.L: possibly delisted; no timezone found
# [**********************88%*****************      ]  22 of 25 completed$STLA.MI: possibly delisted; no timezone found
# [*********************100%***********************]  25 of 25 completed
#
# 3 Failed downloads:
# ['SOGN.PA']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# ['SJP.L', 'STLA.MI']: possibly delisted; no timezone found
# [***************       32%                       ]  8 of 25 completed$TCFP.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*****************     36%                       ]  9 of 25 completed$SY1G.DE: possibly delisted; no timezone found
# [*******************   40%                       ]  10 of 25 completed$STM.MI: possibly delisted; no timezone found
# [**********************76%***********            ]  19 of 25 completed$SWRK: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*********************100%***********************]  25 of 25 completed
#
# 4 Failed downloads:
# ['TCFP.PA', 'SWRK']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# ['SY1G.DE', 'STM.MI']: possibly delisted; no timezone found
# [**********************92%*******************    ]  23 of 25 completed$TTEF.PA: possibly delisted; no timezone found
# [*********************100%***********************]  24 of 25 completed
#
# 1 Failed download:
# ['TTEF.PA']: possibly delisted; no timezone found
# [*******************   40%                       ]  10 of 25 completed$VOWG_P.DE: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*********************100%***********************]  25 of 25 completed
#
# 1 Failed download:
# ['VOWG_P.DE']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*********************100%***********************]  25 of 25 completed
# [**********************71%*********              ]  5 of 7 completed$SQ: possibly delisted; no timezone found
# [*********************100%***********************]  6 of 7 completed
#
# 1 Failed download:
# ['SQ']: possibly delisted; no timezone found

# %%
equities['yfin_valid'] = equities['yfinance_ticker'].map(
    yfin_prices.transpose()['2026-02-03']
)
equities['distance'] = (equities['lseg_valid'] - equities['yfin_valid']).abs() / equities['lseg_valid']
equities[equities['distance'] > 0.005]
# Out:
#     Instrument           Company Common Name Exchange Code  \
# 140      CFG.N  Citizens Financial Group Inc           NYS
#
#     Country ISO Code of Headquarters  GICS Sub-Industry Code CF_CURR  \
# 140                               US                40101015     USD
#
#     yfinance_ticker  lseg_valid  yfin_valid  distance
# 140             CFG       65.97   65.510002  0.006973

# %%
equities = pd.read_csv('equities_saved.csv')

# %%
# Attempt to build ticker for those that failed
# =============================================
problems = equities['yfin_valid'].isna()
print(f"Found {problems.sum()} problematic tickers.")

print(
    equities['Instrument']
    .apply(lambda x: x.split('.')[-1] if '.' in x else None)
    .unique()
)

RIC_TO_YAHOO_SUFFIX = {
    '.N': '',       # NYSE
    '.O': '',       # NASDAQ
    '.OQ': '',      # NASDAQ
    '.K': '',       # NYSE (alternate)
    '.A': '',       # NYSE Amex
    '.L': '.L',     # London Stock Exchange
    '.DE': '.DE',   # Frankfurt (Xetra)
    '.AS': '.AS',   # Amsterdam
    '.PA': '.PA',   # Paris
    '.BR': '.BR',   # Brussels
    '.MC': '.MC',   # Madrid
    '.MI': '.MI',   # Milan
    '.CO': '.CO',   # Copenhagen
    '.HE': '.HE',   # Helsinki
    '.S': '.ST',    # Stockholm
    '.SW': '.SW',   # Swiss Exchange
    '.TO': '.TO',   # Toronto
}

equities.loc[problems, 'yfinance_ticker'] = (
    equities.loc[problems, 'Instrument']
    .apply(
        lambda x: x.split('.')[0] + RIC_TO_YAHOO_SUFFIX.get(
                ('.' + x.split('.')[-1]), ''
            )
    )
)
# Out:
# Found 53 problematic tickers.
# ['N' 'L' 'OQ' 'BR' 'PA' 'AS' 'DE' 'K' 'MC' 'Z' 'MI' 'CO' 'TO' 'O' 'HE' 'S']

# %%
# Re-fetch yahpoo prices for corrected tickers
# ==========================================
problems = equities['yfin_valid'].isna()
print(f"Re-fetching {problems.sum()} problematic tickers.")

yfin = equities.loc[problems, 'yfinance_ticker'].to_list()
retrievals = [] 
# Limit tickers to stay safe
size = 25
for i in range(0, len(yfin), size):
    batch = yfin[i:min(i+size, len(yfin))]
    prices = yf.download(
        tickers=batch,
        start='2026-02-01',
        end='2026-02-05',
    )
    close = prices.xs('Close', axis=1, level=0)
    close = close.transpose()['2026-02-03']
    retrievals.append(close)
    time.sleep(1)  # Be nice to Yahoo's servers

yfin_prices = pd.concat(retrievals, axis=0)
equities.loc[problems, 'yfin_valid'] = equities.loc[problems, 'yfinance_ticker'].map(
    yfin_prices
)
equities['distance'] = (equities['lseg_valid'] - equities['yfin_valid']).abs() / equities['lseg_valid']
equities[equities['distance'] > 0.005]
print(equities['yfin_valid'].isna().sum())
# Out:
# Re-fetching 53 problematic tickers.
# $HNKG_P.DE: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [                       0%                       ]$BKGH.L: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [********              16%                       ]  4 of 25 completed$DAST.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********            20%                       ]  5 of 25 completed$AIRP.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# $AXAF.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [************          24%                       ]  6 of 25 completed$EUFI.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*************         28%                       ]  7 of 25 completed$FOUG.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [***************       32%                       ]  8 of 25 completed$DB1GN.DE: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*****************     36%                       ]  9 of 25 completed$HNRGN.DE: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*******************   40%                       ]  10 of 25 completed$CAGR.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [********************* 44%                       ]  11 of 25 completed$FMEG.DE: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************48%                       ]  12 of 25 completed$G1AG.DE: possibly delisted; no timezone found
# [**********************52%                       ]  13 of 25 completed$AUTOA.L: possibly delisted; no timezone found
# [**********************56%**                     ]  14 of 25 completed$BT.L: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************60%****                   ]  15 of 25 completed$DANO.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************64%******                 ]  16 of 25 completed$FREG.DE: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************72%**********             ]  18 of 25 completed$DHLN.DE: possibly delisted; no timezone found
# [**********************76%***********            ]  19 of 25 completed$ESLX.PA: possibly delisted; no timezone found
# [**********************80%*************          ]  20 of 25 completed$BFB: possibly delisted; no timezone found
# [**********************84%***************        ]  21 of 25 completed$BOUY.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************88%*****************      ]  22 of 25 completed$G24N.DE: possibly delisted; no timezone found
# [**********************92%*******************    ]  23 of 25 completedHTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: BNRGN.DE"}}}
# $BNRGN.DE: possibly delisted; no timezone found
# [*********************100%***********************]  25 of 25 completed
#
# 22 Failed downloads:
# ['HNKG_P.DE', 'BKGH.L', 'DAST.PA', 'AIRP.PA', 'AXAF.PA', 'EUFI.PA', 'FOUG.PA', 'DB1GN.DE', 'HNRGN.DE', 'CAGR.PA', 'FMEG.DE', 'BT.L', 'DANO.PA', 'FREG.DE', 'BOUY.PA']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# ['G1AG.DE', 'AUTOA.L', 'DHLN.DE', 'ESLX.PA', 'BFB', 'G24N.DE', 'BNRGN.DE']: possibly delisted; no timezone found
# $LVMH.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [                       0%                       ]$PUBP.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [********              16%                       ]  4 of 25 completed$TCFP.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********            20%                       ]  5 of 25 completed$RENA.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [************          24%                       ]  6 of 25 completed$SASY.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [*************         28%                       ]  7 of 25 completed$SGOB.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [***************       32%                       ]  8 of 25 completed$SY1G.DE: possibly delisted; no timezone found
# [*******************   40%                       ]  10 of 25 completed$ORAN.PA: possibly delisted; no timezone found
# [********************* 44%                       ]  11 of 25 completed$PSHG_P.DE: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************48%                       ]  12 of 25 completed$SCHN.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************52%                       ]  13 of 25 completed$PERP.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************56%**                     ]  14 of 25 completed$HRMS.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************60%****                   ]  15 of 25 completed$SOGN.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************64%******                 ]  16 of 25 completed$MICP.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************68%********               ]  17 of 25 completed$PRTP.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************72%**********             ]  18 of 25 completed$MRCG.DE: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [**********************80%*************          ]  20 of 25 completed$LEGD.PA: possibly delisted; no timezone found
# [**********************84%***************        ]  21 of 25 completed$NDAFI.HE: possibly delisted; no timezone found
# [**********************88%*****************      ]  22 of 25 completed$SJP.L: possibly delisted; no timezone found
# [**********************92%*******************    ]  23 of 25 completed$MRON.L: possibly delisted; no timezone found
# [*********************100%***********************]  25 of 25 completed
#
# 20 Failed downloads:
# ['LVMH.PA', 'PUBP.PA', 'TCFP.PA', 'RENA.PA', 'SASY.PA', 'SGOB.PA', 'PSHG_P.DE', 'SCHN.PA', 'PERP.PA', 'HRMS.PA', 'SOGN.PA', 'MICP.PA', 'PRTP.PA', 'MRCG.DE']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# ['SY1G.DE', 'ORAN.PA', 'LEGD.PA', 'NDAFI.HE', 'SJP.L', 'MRON.L']: possibly delisted; no timezone found
# [                       0%                       ]$VOWG_P.DE: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# $TTEF.PA: possibly delisted; no timezone found
# [*********************100%***********************]  3 of 3 completed
#
# 2 Failed downloads:
# ['VOWG_P.DE']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# ['TTEF.PA']: possibly delisted; no timezone found
# 44

# %% [markdown]
# Fixed some, but not all :(

# %%
# Remaing problems
remaining_problems = equities['yfin_valid'].isna()

# Trying a fix with copilot
SPECIAL_RIC_TO_YAHOO = {
    'AIRP.PA': 'AI.PA',
    'AUTOA.L': 'AUTO.L',
    'AXAF.PA': 'CS.PA',
    'BFb.N': 'BF-B',
    'BKGH.L': 'BKG.L',
    'BNRGn.DE': 'BNRG.DE',
    'BOUY.PA': 'EN.PA',
    'BT.L': 'BT-A.L',
    'CAGR.PA': 'CAF.PA',
    'DANO.PA': 'BN.PA',
    'DAST.PA': 'DSY.PA',
    'DB1Gn.DE': 'DB1.DE',
    'DHLn.DE': 'DHL.DE',
    'ESLX.PA': 'ESI.PA',
    'EUFI.PA': 'URW.AS',
    'FMEG.DE': 'FME.DE',
    'FOUG.PA': 'FOUG.PA',
    'FREG.DE': 'FRE.DE',
    'G1AG.DE': 'G1A.DE',
    'G24n.DE': 'G24.DE',
    'HNKG_p.DE': 'HNR1.DE',
    'HNRGn.DE': 'HNR.DE',
    'HRMS.PA': 'RMS.PA',
    'LEGD.PA': 'LI.PA',
    'LVMH.PA': 'MC.PA',
    'MICP.PA': 'ML.PA',
    'MRCG.DE': 'MRK.DE',
    'MRON.L': 'MRO.L',
    'NDAFI.HE': 'NESTE.HE',
    'ORAN.PA': 'ORA.PA',
    'PERP.PA': 'RI.PA',
    'PRTP.PA': 'UG.PA',
    'PSHG_p.DE': 'PAH3.DE',
    'PUBP.PA': 'PUB.PA',
    'RENA.PA': 'RNO.PA',
    'SASY.PA': 'SAN.PA',
    'SCHN.PA': 'SGO.PA',
    'SGOB.PA': 'GLE.PA',
    'SJP.L': 'SJP.L',
    'SOGN.PA': 'SW.PA',
    'SY1G.DE': 'SY1.DE',
    'TCFP.PA': 'HO.PA',
    'TTEF.PA': 'FP.PA',
    'VOWG_p.DE': 'VOW3.DE',
}

# Apply fixes
equities.loc[remaining_problems, 'yfinance_ticker'] = (
    equities.loc[remaining_problems, 'Instrument'].replace(SPECIAL_RIC_TO_YAHOO)
)

# Again re-fetch yahpoo prices for corrected tickers
# ==========================================
yfin = equities.loc[remaining_problems, 'yfinance_ticker'].to_list()
retrievals = [] 
# Limit tickers to stay safe
size = 25
for i in range(0, len(yfin), size):
    batch = yfin[i:min(i+size, len(yfin))]
    prices = yf.download(
        tickers=batch,
        start='2026-02-01',
        end='2026-02-05',
    )
    close = prices.xs('Close', axis=1, level=0)
    close = close.transpose()['2026-02-03']
    retrievals.append(close)
    time.sleep(1)  # Be nice to Yahoo's servers

yfin_prices = pd.concat(retrievals, axis=0)
equities.loc[remaining_problems, 'yfin_valid'] = equities.loc[remaining_problems, 'yfinance_ticker'].map(
    yfin_prices
)
equities['distance'] = (equities['lseg_valid'] - equities['yfin_valid']).abs() / equities['lseg_valid']
print(equities[equities['distance'] > 0.005])
print(equities['yfin_valid'].isna().sum())
# Out:
# $FOUG.PA: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# [***************       32%                       ]  8 of 25 completed$HNR.DE: possibly delisted; no timezone found
# [********************* 44%                       ]  11 of 25 completed$URW.AS: possibly delisted; no timezone found
# $BNRG.DE: possibly delisted; no timezone found
# [**********************92%*******************    ]  23 of 25 completed$ESI.PA: possibly delisted; no timezone found
# [*********************100%***********************]  25 of 25 completed
#
# 5 Failed downloads:
# ['FOUG.PA']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05)
# ['HNR.DE', 'URW.AS', 'BNRG.DE', 'ESI.PA']: possibly delisted; no timezone found
# $SJP.L: possibly delisted; no timezone found
# [**********************58%***                    ]  11 of 19 completed$FP.PA: possibly delisted; no timezone found
# [**********************89%******************     ]  17 of 19 completed$UG.PA: possibly delisted; no timezone found
# [*********************100%***********************]  18 of 19 completed
# [*********************100%***********************]  18 of 19 completed
# 3 Failed downloads:
# ['SJP.L', 'FP.PA', 'UG.PA']: possibly delisted; no timezone found
#     Instrument           Company Common Name Exchange Code  \
# 120    CAGR.PA            Credit Agricole SA           PAR
# 138      CFG.N  Citizens Financial Group Inc           NYS
# 326  HNKG_p.DE           Henkel AG & Co KGaA           GER
# 403    LEGD.PA                    Legrand SA           PAR
# 477   NDAFI.HE               Nordea Bank Abp           HEX
# 590    SCHN.PA         Schneider Electric SE           PAR
# 595    SGOB.PA  Compagnie de Saint Gobain SA           PAR
# 614    SOGN.PA           Societe Generale SA           PAR
#
#     Country ISO Code of Headquarters  GICS Sub-Industry Code CF_CURR  \
# 120                               FR                40101010     EUR
# 138                               US                40101015     USD
# 326                               DE                30301010     EUR
# 403                               FR                20104010     EUR
# 477                               FI                40101010     EUR
# 590                               FR                20104010     EUR
# 595                               FR                20102010     EUR
# 614                               FR                40101010     EUR
#
#     yfinance_ticker  lseg_valid  yfin_valid  distance
# 120          CAF.PA      18.745  119.500000  5.375033
# 138             CFG      65.970   65.510002  0.006973
# 326         HNR1.DE      75.540  242.800003  2.214191
# 403           LI.PA     137.200   31.959999  0.767055
# 477        NESTE.HE      16.905   21.610001  0.278320
# 590          SGO.PA     249.650   86.260002  0.654476
# 595          GLE.PA      86.260   76.599998  0.111987
# 614           SW.PA      76.600   43.700001  0.429504
# 8

# %%
# Fix the remaining manually
empties = equities['yfin_valid'].isna()
suspects = equities['distance'] > 0.005
equities[empties | suspects]
# Out:
#     Instrument           Company Common Name Exchange Code  \
# 104   BNRGn.DE                   Brenntag SE           GER
# 120    CAGR.PA            Credit Agricole SA           PAR
# 138      CFG.N  Citizens Financial Group Inc           NYS
# 247    ESLX.PA           EssilorLuxottica SA           PAR
# 251    EUFI.PA        Eurofins Scientific SE           PAR
# 278    FOUG.PA                    Eiffage SA           PAR
# 326  HNKG_p.DE           Henkel AG & Co KGaA           GER
# 327   HNRGn.DE             Hannover Rueck SE           GER
# 403    LEGD.PA                    Legrand SA           PAR
# 477   NDAFI.HE               Nordea Bank Abp           HEX
# 539    PRTP.PA                     Kering SA           PAR
# 590    SCHN.PA         Schneider Electric SE           PAR
# 595    SGOB.PA  Compagnie de Saint Gobain SA           PAR
# 604      SJP.L          St James's Place PLC           LSE
# 614    SOGN.PA           Societe Generale SA           PAR
# 667    TTEF.PA              TotalEnergies SE           PAR
#
#     Country ISO Code of Headquarters  GICS Sub-Industry Code CF_CURR  \
# 104                               DE                20107010     EUR
# 120                               FR                40101010     EUR
# 138                               US                40101015     USD
# 247                               FR                35101020     EUR
# 251                               LU                35203010     EUR
# 278                               FR                20103010     EUR
# 326                               DE                30301010     EUR
# 327                               DE                40301050     EUR
# 403                               FR                20104010     EUR
# 477                               FI                40101010     EUR
# 539                               FR                25203010     EUR
# 590                               FR                20104010     EUR
# 595                               FR                20102010     EUR
# 604                               GB                40203010     GBp
# 614                               FR                40101010     EUR
# 667                               FR                10102010     EUR
#
#     yfinance_ticker  lseg_valid  yfin_valid  distance
# 104         BNRG.DE      51.820         NaN       NaN
# 120          CAF.PA      18.745  119.500000  5.375033
# 138             CFG      65.970   65.510002  0.006973
# 247          ESI.PA     255.900         NaN       NaN
# 251          URW.AS      67.880         NaN       NaN
# 278         FOUG.PA     127.600         NaN       NaN
# 326         HNR1.DE      75.540  242.800003  2.214191
# 327          HNR.DE     242.800         NaN       NaN
# 403           LI.PA     137.200   31.959999  0.767055
# 477        NESTE.HE      16.905   21.610001  0.278320
# 539           UG.PA     258.550         NaN       NaN
# 590          SGO.PA     249.650   86.260002  0.654476
# 595          GLE.PA      86.260   76.599998  0.111987
# 604           SJP.L    1553.000         NaN       NaN
# 614           SW.PA      76.600   43.700001  0.429504
# 667           FP.PA      61.480         NaN       NaN

# %%
MANUAL_FIX = {
    'BALL.N': 'BALL',
    'BNRGn.DE': 'BNR.DE',
    'CAGR.PA': 'ACA.PA',
    'CFG.N': 'CFG',
    'DOC.N': 'DOC',
    'ESLX.PA': 'EL.PA',
    'EUFI.PA': 'ERF.PA',
    'FOUG.PA': 'FGR.PA',
    'HNKG_p.DE': 'HEN3.DE',
    'HNRGn.DE': 'HNR1.DE',
    'LEGD.PA': 'LR.PA',
    'LLYVK.OQ': 'LLYVK',
    'NDAFI.HE': 'NDA-FI.HE',
    'PRTP.PA': 'KER.PA',
    'SCHN.PA': 'SU.PA',
    'SGOB.PA': 'SGO.PA',
    'SJP.L': 'STJ.L',
    'SOGN.PA': 'GLE.PA',
    'SW.N': 'SW',
    'TTEF.PA': 'TTE.PA',
    'XYZ.N': 'XYZ'
}

equities.loc[empties | suspects, 'yfinance_ticker'] = (
    equities.loc[empties | suspects, 'Instrument'].replace(MANUAL_FIX)
)

# %% [markdown]
# Last check ?

# %%
# Retrieve price from yfinance to compare
yfin = equities['yfinance_ticker'].to_list()

retrievals = []

# Limit tickers to stay safe
size = 25
for i in range(0, len(yfin), size):
    batch = yfin[i:min(i+size, len(yfin))]
    prices = yf.download(
        tickers=batch,
        start='2026-02-01',
        end='2026-02-05',
    )
    close = prices.xs('Close', axis=1, level=0)
    retrievals.append(close)
    time.sleep(1)  # Be nice to Yahoo's servers

yfin_prices = pd.concat(retrievals, axis=1)

equities['yfin_valid'] = equities['yfinance_ticker'].map(
    yfin_prices.transpose()['2026-02-03']
)
equities['distance'] = (equities['lseg_valid'] - equities['yfin_valid']).abs() / equities['lseg_valid']
# Out:
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [********************* 44%                       ]  11 of 25 completed$EVR.L: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05) (Yahoo error = "No data found, symbol may be delisted")
# [*********************100%***********************]  25 of 25 completed
#
# 1 Failed download:
# ['EVR.L']: possibly delisted; no price data found  (1d 2026-02-01 -> 2026-02-05) (Yahoo error = "No data found, symbol may be delisted")
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
#
# 1 Failed download:
# ['TSCO']: TypeError("'NoneType' object is not subscriptable")
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  7 of 7 completed

# %%
# Check last stragglers
empties = equities['yfin_valid'].isna()
suspects = equities['distance'] > 0.005
equities[empties | suspects]
# Out:
#     Instrument           Company Common Name Exchange Code  \
# 138      CFG.N  Citizens Financial Group Inc           NYS
# 252     EVRE.L                     EVRAZ plc           LSE
# 598    SHLG.DE       Siemens Healthineers AG           GER
# 661    TSCO.OQ             Tractor Supply Co           NSM
# 689      VLO.N            Valero Energy Corp           NYS
#
#     Country ISO Code of Headquarters  GICS Sub-Industry Code CF_CURR  \
# 138                               US                40101015     USD
# 252                               GB                15104050     GBp
# 598                               DE                35101010     EUR
# 661                               US                25504040     USD
# 689                               US                10102030     USD
#
#     yfinance_ticker  lseg_valid  yfin_valid  distance
# 138             CFG       65.97   65.510002  0.006973
# 252           EVR.L         NaN         NaN       NaN
# 598          SHL.DE       42.15   41.160564  0.023474
# 661            TSCO       53.47         NaN       NaN
# 689             VLO      192.27  191.101242  0.006079

# %% [markdown]
# Small inconstitenties, but data is okay expect one delisted!

# %%
# Drop because unlisted
equities = equities[equities['Instrument'] != 'EVRE.L']

equities
# Out:
#     Instrument         Company Common Name Exchange Code  \
# 0          A.N    Agilent Technologies Inc           NYS
# 1        AAF.L           Airtel Africa PLC           LSE
# 2        AAL.L          Anglo American PLC           LSE
# 3      AAPL.OQ                   Apple Inc           NSM
# 4       ABBV.N                  AbbVie Inc           NYS
# ..         ...                         ...           ...
# 727    ZALG.DE                  Zalando SE           GER
# 728      ZBH.N  Zimmer Biomet Holdings Inc           NYS
# 729    ZBRA.OQ     Zebra Technologies Corp           NSM
# 730      ZS.OQ                 Zscaler Inc           NSM
# 731      ZTS.N                  Zoetis Inc           NYS
#
#     Country ISO Code of Headquarters  GICS Sub-Industry Code CF_CURR  \
# 0                                 US                35203010     USD
# 1                                 GB                50102010     GBp
# 2                                 GB                15104020     GBp
# 3                                 US                45202030     USD
# 4                                 US                35201010     USD
# ..                               ...                     ...     ...
# 727                               DE                25504010     EUR
# 728                               US                35101010     USD
# 729                               US                45203010     USD
# 730                               US                45103020     USD
# 731                               US                35202010     USD
#
#     yfinance_ticker  lseg_valid   yfin_valid      distance
# 0                 A      132.14   132.139999  4.618976e-09
# 1             AAF.L      324.00   324.000000  0.000000e+00
# 2             AAL.L     3700.00  3700.000000  0.000000e+00
# 3              AAPL      269.48   269.480011  4.076862e-08
# 4              ABBV      225.66   225.660004  1.622844e-08
# ..              ...         ...          ...           ...
# 727          ZAL.DE       21.48    21.480000  2.131116e-08
# 728             ZBH       86.18    86.180000  3.541144e-09
# 729            ZBRA      233.16   233.160004  1.570642e-08
# 730              ZS      188.05   188.050003  1.622844e-08
# 731             ZTS      122.41   122.410004  2.991675e-08
#
# [731 rows x 10 columns]

# %%
# Last fields I want from rd (forgot)
fetch = rd.get_data(
    universe=list(equities['Instrument']),
    fields='TR.ISIN',
    parameters={'Endnum': '5000'}
).replace('', pd.NA)

# Identify empty strings as NaN
fetch_map = fetch.set_index('Instrument').to_dict()['ISIN']
equities['isin'] = equities['Instrument'].map(fetch_map)

# %%
# Map the etoro tickers I do have
etoro = pd.read_csv('etoro_ticker_mapper.csv')
etoro_mapper = dict(zip(etoro['LSEG'], etoro['ETORO']))
equities['etoro_ticker'] = equities['Instrument'].map(etoro_mapper)

# %%
# Rename columns
rename_map = {
    'Instrument': 'ric',
    'Company Common Name': 'name',
    'Exchange Code': 'exchange',
    'Country ISO Code of Headquarters': 'country_hq',
    'GICS Sub-Industry Code': 'gics_code',
    'CF_CURR': 'currency',
    'ISIN': 'isin'
}

equities = equities.rename(columns=rename_map)

# Reorder columns and keep only relevant ones
equities = equities[[
    'name', 'isin', 'yfinance_ticker', 'etoro_ticker', 'ric',
    'exchange', 'country_hq', 'currency', 'gics_code'
]]

# %%
equities.to_csv('equities_final.csv', index=False)
